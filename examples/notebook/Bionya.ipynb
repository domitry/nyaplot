# %%
require 'nyaplot'
require 'bionya'
# Out:
# true

# %%
Nyaplot.init_iruby
# Out:
# "<script>\nif(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"http://d3js.org/d3.v3.min\",\"Bionya\":\"https://rawgit.com/domitry/nyaplot/master/lib/bionya/js/release/bionya\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"},\"Bionya\":{\"exports\":\"Bionya\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"https://rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\nrequire(['Bionya'], function(Bionya){window['Bionya']=Bionya;console.log('finished loading Bionya');\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n});\n\t};\n\n\n});\n}\n</script>\n"

# %%
arr = []
10.times do |i|
  arr.push({group: 'group' + i.to_s ,df: Nyaplot::DataFrame.new({axis: ['a', 'b', 'c'], val: [2, 3, 4]})})
end
df = Nyaplot::DataFrame.new(arr)
# Out:
# #<Nyaplot::DataFrame:0xb814e264 @name="844a3ebd-9109-4d06-a7cc-2b132f6abe2e", @rows=[{:group=>"group0", :df=>#<Nyaplot::DataFrame:0xb814ff74 @name="b1438855-6052-4a57-9572-b9a1c22acf60", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group1", :df=>#<Nyaplot::DataFrame:0xb814fc68 @name="512112c9-2fb1-4429-8083-6fd4bd5cbc4b", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group2", :df=>#<Nyaplot::DataFrame:0xb814f95c @name="9c0c9f15-6113-4f1f-b9f3-0f890f31e2dc", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group3", :df=>#<Nyaplot::DataFrame:0xb814f68c @name="cac34c9f-2f51-4a18-b45f-adcd6a55e792", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group4", :df=>#<Nyaplot::DataFrame:0xb814f380 @name="59f80a1c-de12-44bc-bb35-3a86e2aa6e65", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group5", :df=>#<Nyaplot::DataFrame:0xb814f074 @name="63a91fdc-22ce-4e2c-92ba-761b28d43c1a", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group6", :df=>#<Nyaplot::DataFrame:0xb814eda4 @name="af0b17e6-8207-462f-b6e9-6a8378ba23d8", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group7", :df=>#<Nyaplot::DataFrame:0xb814ea98 @name="351a36d4-86b5-4fe3-aa80-f14ee7a31176", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group8", :df=>#<Nyaplot::DataFrame:0xb814e7c8 @name="dc5ad96b-adbd-4369-8976-9c26dd0791cb", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group9", :df=>#<Nyaplot::DataFrame:0xb814e4bc @name="dd1caa02-307d-4862-b3ef-a41868e63c4b", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}]>

# %%
plot = Nyaplot::CircularPlot.new(df, :group, :df)
# Out:
# #<Nyaplot::CircularPlot:0xb81557d0 @properties={:diagrams=>[], :options=>{}, :axis_extra_options=>{:group_by=>:group, :color=>["#253494"]}, :extension=>"Bionya"}, @df=#<Nyaplot::DataFrame:0xb814e264 @name="844a3ebd-9109-4d06-a7cc-2b132f6abe2e", @rows=[{:group=>"group0", :df=>#<Nyaplot::DataFrame:0xb814ff74 @name="b1438855-6052-4a57-9572-b9a1c22acf60", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group1", :df=>#<Nyaplot::DataFrame:0xb814fc68 @name="512112c9-2fb1-4429-8083-6fd4bd5cbc4b", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group2", :df=>#<Nyaplot::DataFrame:0xb814f95c @name="9c0c9f15-6113-4f1f-b9f3-0f890f31e2dc", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group3", :df=>#<Nyaplot::DataFrame:0xb814f68c @name="cac34c9f-2f51-4a18-b45f-adcd6a55e792", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group4", :df=>#<Nyaplot::DataFrame:0xb814f380 @name="59f80a1c-de12-44bc-bb35-3a86e2aa6e65", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group5", :df=>#<Nyaplot::DataFrame:0xb814f074 @name="63a91fdc-22ce-4e2c-92ba-761b28d43c1a", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group6", :df=>#<Nyaplot::DataFrame:0xb814eda4 @name="af0b17e6-8207-462f-b6e9-6a8378ba23d8", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group7", :df=>#<Nyaplot::DataFrame:0xb814ea98 @name="351a36d4-86b5-4fe3-aa80-f14ee7a31176", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group8", :df=>#<Nyaplot::DataFrame:0xb814e7c8 @name="dc5ad96b-adbd-4369-8976-9c26dd0791cb", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}, {:group=>"group9", :df=>#<Nyaplot::DataFrame:0xb814e4bc @name="dd1caa02-307d-4862-b3ef-a41868e63c4b", @rows=[{:axis=>"a", :val=>2}, {:axis=>"b", :val=>3}, {:axis=>"c", :val=>4}]>}]>, @inner_num=0, @outer_num=1, @nested_label=:df>

# %%
plot.add(1, :arc, :axis, :val)
# Out:
# #<Nyaplot::Diagram:0xb81591f0 @properties={:type=>:arc, :options=>{:x=>:axis, :y=>:val, :range=>[0, 4], :layer=>1}, :data=>"844a3ebd-9109-4d06-a7cc-2b132f6abe2e"}>

# %%
plot.show
# Out:
# "<div id='vis-e27ab121-40a4-4312-8aee-3f75a7bd3b96'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"arc\",\"options\":{\"x\":\"axis\",\"y\":\"val\",\"range\":[0,4],\"layer\":1},\"data\":\"844a3ebd-9109-4d06-a7cc-2b132f6abe2e\"}],\"options\":{\"zoom\":true,\"width\":800,\"height\":800,\"axis_extra_options\":{\"group_by\":\"group\",\"color\":[\"#253494\"],\"inner_num\":0,\"outer_num\":2,\"df_id\":\"844a3ebd-9109-4d06-a7cc-2b132f6abe2e\",\"axis\":\"axis\"}},\"axis_extra_options\":{\"group_by\":\"group\",\"color\":[\"#253494\"],\"inner_num\":0,\"outer_num\":2,\"df_id\":\"844a3ebd-9109-4d06-a7cc-2b132f6abe2e\",\"axis\":\"axis\"},\"extension\":\"Bionya\"}],\"data\":{\"844a3ebd-9109-4d06-a7cc-2b132f6abe2e\":[{\"group\":\"group0\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group1\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group2\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group3\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group4\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group5\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group6\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group7\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group8\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]},{\"group\":\"group9\",\"df\":[{\"axis\":\"a\",\"val\":2},{\"axis\":\"b\",\"val\":3},{\"axis\":\"c\",\"val\":4}]}]},\"extension\":[\"Bionya\"]}\n        Nyaplot.core.parse(model, '#vis-e27ab121-40a4-4312-8aee-3f75a7bd3b96');\n    };\n    if(window['Nyaplot']==undefined){\n        window.addEventListener('load_nyaplot', render, false);\n\treturn;\n    }\n    render();\n})();\n</script>\n"

# %%
df = Nyaplot::DataFrame.from_csv('./data/circular/category.csv')
# Out:
# #<Nyaplot::DataFrame:0xb83d0be0 @name="d88171ed-0fc2-4a47-8a38-9f2b7ef693bd", @rows=[{:name=>"chr1", :size=>249250621}, {:name=>"chr2", :size=>243199373}, {:name=>"chr3", :size=>198022430}, {:name=>"chr4", :size=>191154276}, {:name=>"chr5", :size=>180915260}, {:name=>"chr6", :size=>171115067}, {:name=>"chr7", :size=>159138663}, {:name=>"chr8", :size=>146364022}, {:name=>"chr9", :size=>141213431}, {:name=>"chr10", :size=>135534747}, {:name=>"chr11", :size=>135006516}, {:name=>"chr12", :size=>133851895}, {:name=>"chr13", :size=>115169878}, {:name=>"chr14", :size=>107349540}, {:name=>"chr15", :size=>102531392}, {:name=>"chr16", :size=>90354753}, {:name=>"chr17", :size=>81195210}, {:name=>"chr18", :size=>78077248}, {:name=>"chr19", :size=>59128983}, {:name=>"chr20", :size=>63025520}, {:name=>"chr21", :size=>48129895}, {:name=>"chr22", :size=>51304566}, {:name=>"chrx", :size=>155270560}, {:name=>"chry", :size=>59373566}]>

# %%
df2 = Nyaplot::DataFrame.from_csv('./data/circular/hgmd.tsv', {col_sep: "\t"})
# Out:
# #<Nyaplot::DataFrame:0xb8527ea8 @name="1f011ee0-79ea-4c95-a47e-d11141c08be2", @rows=[{:gene_name=>"hs1", :start=>182554557, :end=>187554557, :num1=>0.0, :num2=>12.0}, {:gene_name=>"hs1", :start=>223284528, :end=>228284528, :num1=>0.0, :num2=>15.0}, {:gene_name=>"hs1", :start=>43804340, :end=>48804340, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs1", :start=>20972111, :end=>25972111, :num1=>0.0, :num2=>2.0}, {:gene_name=>"hs1", :start=>1650845, :end=>6650845, :num1=>0.0, :num2=>21.0}, {:gene_name=>"hs1", :start=>223284444, :end=>228284444, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs1", :start=>12252955, :end=>17252955, :num1=>0.0, :num2=>10.0}, {:gene_name=>"hs1", :start=>45797505, :end=>50797505, :num1=>0.0, :num2=>3.0}, {:gene_name=>"hs1", :start=>226555302, :end=>231555302, :num1=>0.0, :num2=>9.0}, {:gene_name=>"hs1", :start=>20977000, :end=>25977000, :num1=>0.0, :num2=>14.0}, {:gene_name=>"hs1", :start=>182551337, :end=>187551337, :num1=>0.0, :num2=>17.0}, {:gene_name=>"hs1", :start=>8030994, :end=>13030994, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs1", :start=>55638075, :end=>60638075, :num1=>0.0, :num2=>20.0}, {:gene_name=>"hs1", :start=>223285200, :end=>228285200, :num1=>0.0, :num2=>3.0}, {:gene_name=>"hs1", :start=>223284599, :end=>228284599, :num1=>0.0, :num2=>7.0}, {:gene_name=>"hs10", :start=>72195439, :end=>77195439, :num1=>0.0, :num2=>10.0}, {:gene_name=>"hs10", :start=>16919052, :end=>21919052, :num1=>0.0, :num2=>2.0}, {:gene_name=>"hs10", :start=>123310871, :end=>128310871, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs10", :start=>131506283, :end=>136506283, :num1=>0.0, :num2=>3.0}, {:gene_name=>"hs10", :start=>43620335, :end=>48620335, :num1=>0.0, :num2=>2.0}, {:gene_name=>"hs10", :start=>102295836, :end=>107295836, :num1=>0.0, :num2=>4.0}, {:gene_name=>"hs10", :start=>22839628, :end=>27839628, :num1=>0.0, :num2=>10.0}, {:gene_name=>"hs10", :start=>131565064, :end=>136565064, :num1=>0.0, :num2=>8.0}, {:gene_name=>"hs10", :start=>121086097, :end=>126086097, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs10", :start=>90762801, :end=>95762801, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs10", :start=>43610119, :end=>48610119, :num1=>0.0, :num2=>11.0}, {:gene_name=>"hs10", :start=>131565170, :end=>136565170, :num1=>0.0, :num2=>5.0}, {:gene_name=>"hs10", :start=>68040325, :end=>73040325, :num1=>0.0, :num2=>10.0}, {:gene_name=>"hs10", :start=>97174352, :end=>102174352, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs11", :start=>108175462, :end=>113175462, :num1=>0.0, :num2=>2.0}, {:gene_name=>"hs11", :start=>67353579, :end=>72353579, :num1=>0.0, :num2=>2.0}, {:gene_name=>"hs11", :start=>67250676, :end=>72250676, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs11", :start=>67202156, :end=>72202156, :num1=>0.0, :num2=>3.0}, {:gene_name=>"hs11", :start=>68201295, :end=>73201295, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs11", :start=>67352689, :end=>72352689, :num1=>0.0, :num2=>13.0}, {:gene_name=>"hs11", :start=>48146622, :end=>53146622, :num1=>0.0, :num2=>5.0}, {:gene_name=>"hs11", :start=>113270828, :end=>118270828, :num1=>0.0, :num2=>3.0}, {:gene_name=>"hs11", :start=>113270160, :end=>118270160, :num1=>0.0, :num2=>14.0}, {:gene_name=>"hs11", :start=>68174189, :end=>73174189, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs11", :start=>111635566, :end=>116635566, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs11", :start=>108160350, :end=>113160350, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs11", :start=>48145375, :end=>53145375, :num1=>0.0, :num2=>5.0}, {:gene_name=>"hs12", :start=>4479549, :end=>9479549, :num1=>0.0, :num2=>1.0}, {:gene_name=>"hs12", :start=>121712077, :end=>126712077, :num1=>0.0, :num2=>3.0}, {:gene_name=>"hs12", :start=>121592689, :end=>126592689, :num1=>0.0, :num2=>4.0}, {:gene_name=>"hs12", :start=>121622196, :end=>126622196, :num1=>0.0, :num2=>3.0}, {:gene_name=>"hs12", :start=>121432117, :end=>126432117, :num1=>0.0, :num2=>6.0}, {:gene_name=>"hs12", :start=>12871099, :end=>17871099, :num1=>0.0, :num2=>5.0}, {:gene_name=>"hs12", :start=>12161510 ...

# %%
df3 = Nyaplot::DataFrame.from_csv('./data/circular/genes_hgmd.tsv', {col_sep: "\t"})
# Out:
# #<Nyaplot::DataFrame:0xb7e9c214 @name="cd30c249-95f4-4539-9e14-cebbed1628d1", @rows=[{:gene_name=>"hs1", :start=>182554557, :end=>182555057, :name=>"RNASEL"}, {:gene_name=>"hs1", :start=>223284528, :end=>223285028, :name=>"TLR5"}, {:gene_name=>"hs1", :start=>43804340, :end=>43804840, :name=>"MPL"}, {:gene_name=>"hs1", :start=>20972111, :end=>20972611, :name=>"PINK1"}, {:gene_name=>"hs1", :start=>1650845, :end=>1651345, :name=>"CDK11A"}, {:gene_name=>"hs1", :start=>223284444, :end=>223284944, :name=>"TLR5"}, {:gene_name=>"hs1", :start=>12252955, :end=>12253455, :name=>"TNFRSF1B"}, {:gene_name=>"hs1", :start=>45797505, :end=>45798005, :name=>"MUTYH"}, {:gene_name=>"hs1", :start=>226555302, :end=>226555802, :name=>"PARP1"}, {:gene_name=>"hs1", :start=>20977000, :end=>20977500, :name=>"PINK1"}, {:gene_name=>"hs1", :start=>182551337, :end=>182551837, :name=>"RNASEL"}, {:gene_name=>"hs1", :start=>8030994, :end=>8031494, :name=>"PARK7"}, {:gene_name=>"hs1", :start=>55638075, :end=>55638575, :name=>"USP24"}, {:gene_name=>"hs1", :start=>223285200, :end=>223285700, :name=>"TLR5"}, {:gene_name=>"hs1", :start=>223284599, :end=>223285099, :name=>"TLR5"}, {:gene_name=>"hs10", :start=>72195439, :end=>72195939, :name=>"NODAL"}, {:gene_name=>"hs10", :start=>16919052, :end=>16919552, :name=>"CUBN"}, {:gene_name=>"hs10", :start=>123310871, :end=>123311371, :name=>"FGFR2"}, {:gene_name=>"hs10", :start=>131506283, :end=>131506783, :name=>"MGMT"}, {:gene_name=>"hs10", :start=>43620335, :end=>43620835, :name=>"RET"}, {:gene_name=>"hs10", :start=>102295836, :end=>102296336, :name=>"HIF1AN"}, {:gene_name=>"hs10", :start=>22839628, :end=>22840128, :name=>"PIP4K2A"}, {:gene_name=>"hs10", :start=>131565064, :end=>131565564, :name=>"MGMT"}, {:gene_name=>"hs10", :start=>121086097, :end=>121086597, :name=>"GRK5"}, {:gene_name=>"hs10", :start=>90762801, :end=>90763301, :name=>"FAS"}, {:gene_name=>"hs10", :start=>43610119, :end=>43610619, :name=>"RET"}, {:gene_name=>"hs10", :start=>131565170, :end=>131565670, :name=>"MGMT"}, {:gene_name=>"hs10", :start=>68040325, :end=>68040825, :name=>"CTNNA3"}, {:gene_name=>"hs10", :start=>97174352, :end=>97174852, :name=>"SORBS1"}, {:gene_name=>"hs11", :start=>108175462, :end=>108175962, :name=>"ATM"}, {:gene_name=>"hs11", :start=>67353579, :end=>67354079, :name=>"GSTP1"}, {:gene_name=>"hs11", :start=>67250676, :end=>67251176, :name=>"AIP"}, {:gene_name=>"hs11", :start=>67202156, :end=>67202656, :name=>"RPS6KB2"}, {:gene_name=>"hs11", :start=>68201295, :end=>68201795, :name=>"LRP5"}, {:gene_name=>"hs11", :start=>67352689, :end=>67353189, :name=>"GSTP1"}, {:gene_name=>"hs11", :start=>48146622, :end=>48147122, :name=>"PTPRJ"}, {:gene_name=>"hs11", :start=>113270828, :end=>113271328, :name=>"ANKK1"}, {:gene_name=>"hs11", :start=>113270160, :end=>113270660, :name=>"ANKK1"}, {:gene_name=>"hs11", :start=>68174189, :end=>68174689, :name=>"LRP5"}, {:gene_name=>"hs11", :start=>111635566, :end=>111636066, :name=>"PPP2R1B"}, {:gene_name=>"hs11", :start=>108160350, :end=>108160850, :name=>"ATM"}, {:gene_name=>"hs11", :start=>48145375, :end=>48145875, :name=>"PTPRJ"}, {:gene_name=>"hs12", :start=>4479549, :end=>4480049, :name=>"FGF23"}, {:gene_name=>"hs12", :start=>121712077, :end=>121712577, :name=>"CAMKK2"}, {:gene_name=>"hs12", :start=>121592689, :end=>121593189, :name=>"P2RX7"}, {:gene_name=>"hs12", :start=>121622196, :end=>121622696, :name=>"P2RX7"}, {:gene_name=>"hs12", :start=>121432117, :end=>121432617, :name=>"HNF1A"}, {:gene_name=>"hs12", :start=>12871099, :end=>12871599, :name=>"CDKN1B"}, {:gene_name=>"hs12", :start=>121615103, :end=>121615603, :name=>"P2RX7"}, {:gene_name=>"hs12", :start=>40702911, :end=>40703411, :name=>"LRRK2"}, {:gene_name=>"hs12", :start=>121622304, :end=>121622804, :name=>"P2RX7"}, {:gene_name=>"hs12", :start=>44180295, :end=>44180795, :name=>"IRAK4"}, {:gene_name=>"hs12", :start=>40713901, :end=>40714401, :name=>"LRRK2"}, {:gene_name=>"hs12", :start=>57865821, :end=>57866321, :name=>"GLI1"}, {:gene_na ...

# %%
hash2 = {}
df3.each_row do |row|
  chr_name = "chr" + row[:gene_name].match(/hs(.+)/)[1]
  hash2[chr_name] ||= []
  hash2[chr_name].push({locale: row[:start], name: row[:name]})
end
""
# Out:
# ""

# %%
hash = {}
df2.each_row do |row|
  chr_name = "chr" + row[:gene_name].match(/hs(.+)/)[1]
  hash[chr_name] ||= []
  hash[chr_name].push({start: row[:start], val: row[:num2]})
end
""
# Out:
# ""

# %%
bin_size = df.size.max/50
chr_name = df.column(:name).to_a
nested = df.column(:size).to_a.map.with_index do |size, i|
  vals = hash[chr_name[i]]
  names = hash2[chr_name[i]]
  vals = [] if vals.nil?
  names = [] if names.nil?
  raw = Array.new(size/bin_size, 0).map.with_index {|val, i|
    val = vals.reduce(0){|memo, v| next memo + v[:val] if v[:start] > i*bin_size && v[:start] < (i+1)*bin_size; memo}
    name = names.select {|name| name[:locale] > i*bin_size && name[:locale] < (i+1)*bin_size}
    {axis: i*bin_size, val: val, name: (name.length==0 ? '' : name[0][:name])}
  }
  Nyaplot::DataFrame.new(raw)
end
df.df = nested
df
# Out:
# #<Nyaplot::DataFrame:0xb83d0be0 @name="d88171ed-0fc2-4a47-8a38-9f2b7ef693bd", @rows=[{:name=>"chr1", :size=>249250621, :df=>#<Nyaplot::DataFrame:0xb7eda0f0 @name="13d1350d-58e8-47a6-b4f7-ba06f3f63a0c", @rows=[{:axis=>0, :val=>21.0, :name=>"CDK11A"}, {:axis=>4985012, :val=>1.0, :name=>"PARK7"}, {:axis=>9970024, :val=>10.0, :name=>"TNFRSF1B"}, {:axis=>14955036, :val=>0, :name=>""}, {:axis=>19940048, :val=>16.0, :name=>"PINK1"}, {:axis=>24925060, :val=>0, :name=>""}, {:axis=>29910072, :val=>0, :name=>""}, {:axis=>34895084, :val=>0, :name=>""}, {:axis=>39880096, :val=>1.0, :name=>"MPL"}, {:axis=>44865108, :val=>3.0, :name=>"MUTYH"}, {:axis=>49850120, :val=>0, :name=>""}, {:axis=>54835132, :val=>20.0, :name=>"USP24"}, {:axis=>59820144, :val=>0, :name=>""}, {:axis=>64805156, :val=>0, :name=>""}, {:axis=>69790168, :val=>0, :name=>""}, {:axis=>74775180, :val=>0, :name=>""}, {:axis=>79760192, :val=>0, :name=>""}, {:axis=>84745204, :val=>0, :name=>""}, {:axis=>89730216, :val=>0, :name=>""}, {:axis=>94715228, :val=>0, :name=>""}, {:axis=>99700240, :val=>0, :name=>""}, {:axis=>104685252, :val=>0, :name=>""}, {:axis=>109670264, :val=>0, :name=>""}, {:axis=>114655276, :val=>0, :name=>""}, {:axis=>119640288, :val=>0, :name=>""}, {:axis=>124625300, :val=>0, :name=>""}, {:axis=>129610312, :val=>0, :name=>""}, {:axis=>134595324, :val=>0, :name=>""}, {:axis=>139580336, :val=>0, :name=>""}, {:axis=>144565348, :val=>0, :name=>""}, {:axis=>149550360, :val=>0, :name=>""}, {:axis=>154535372, :val=>0, :name=>""}, {:axis=>159520384, :val=>0, :name=>""}, {:axis=>164505396, :val=>0, :name=>""}, {:axis=>169490408, :val=>0, :name=>""}, {:axis=>174475420, :val=>0, :name=>""}, {:axis=>179460432, :val=>29.0, :name=>"RNASEL"}, {:axis=>184445444, :val=>0, :name=>""}, {:axis=>189430456, :val=>0, :name=>""}, {:axis=>194415468, :val=>0, :name=>""}, {:axis=>199400480, :val=>0, :name=>""}, {:axis=>204385492, :val=>0, :name=>""}, {:axis=>209370504, :val=>0, :name=>""}, {:axis=>214355516, :val=>0, :name=>""}, {:axis=>219340528, :val=>26.0, :name=>"TLR5"}, {:axis=>224325540, :val=>9.0, :name=>"PARP1"}, {:axis=>229310552, :val=>0, :name=>""}, {:axis=>234295564, :val=>0, :name=>""}, {:axis=>239280576, :val=>0, :name=>""}, {:axis=>244265588, :val=>0, :name=>""}]>}, {:name=>"chr2", :size=>243199373, :df=>#<Nyaplot::DataFrame:0xb7ee331c @name="d73fba21-fa0c-4b3b-b2dc-3c1976b32053", @rows=[{:axis=>0, :val=>0, :name=>""}, {:axis=>4985012, :val=>0, :name=>""}, {:axis=>9970024, :val=>11.0, :name=>"ROCK2"}, {:axis=>14955036, :val=>0, :name=>""}, {:axis=>19940048, :val=>0, :name=>""}, {:axis=>24925060, :val=>0, :name=>""}, {:axis=>29910072, :val=>0, :name=>""}, {:axis=>34895084, :val=>0, :name=>""}, {:axis=>39880096, :val=>0, :name=>""}, {:axis=>44865108, :val=>5.0, :name=>"MSH6"}, {:axis=>49850120, :val=>0, :name=>""}, {:axis=>54835132, :val=>0, :name=>""}, {:axis=>59820144, :val=>0, :name=>""}, {:axis=>64805156, :val=>0, :name=>""}, {:axis=>69790168, :val=>0, :name=>""}, {:axis=>74775180, :val=>0, :name=>""}, {:axis=>79760192, :val=>0, :name=>""}, {:axis=>84745204, :val=>0, :name=>""}, {:axis=>89730216, :val=>0, :name=>""}, {:axis=>94715228, :val=>11.0, :name=>"INPP4A"}, {:axis=>99700240, :val=>0, :name=>""}, {:axis=>104685252, :val=>0, :name=>""}, {:axis=>109670264, :val=>0, :name=>""}, {:axis=>114655276, :val=>0, :name=>""}, {:axis=>119640288, :val=>1.0, :name=>"GLI2"}, {:axis=>124625300, :val=>0, :name=>""}, {:axis=>129610312, :val=>0, :name=>""}, {:axis=>134595324, :val=>0, :name=>""}, {:axis=>139580336, :val=>0, :name=>""}, {:axis=>144565348, :val=>0, :name=>""}, {:axis=>149550360, :val=>0, :name=>""}, {:axis=>154535372, :val=>0, :name=>""}, {:axis=>159520384, :val=>1.0, :name=>"DPP4"}, {:axis=>164505396, :val=>0, :name=>""}, {:axis=>169490408, :val=>2.0, :name=>"LRP2"}, {:axis=>174475420, :val=>0, :name=>""}, {:axis=>179460432, :val=>6.0, :name=>"FRZB"}, {:axis=>184445444, :val=>0, :name=>""}, {:axis=>189430456, :val=>0, :name=>""}, {:axis=>194415468, :val=>0, :name=>""}, ...

# %%
df.name = df.column(:name).to_a.map{|name| name.match(/chr(.+)/)[1]}
df
# Out:
# #<Nyaplot::DataFrame:0xb83d0be0 @name="d88171ed-0fc2-4a47-8a38-9f2b7ef693bd", @rows=[{:name=>"1", :size=>249250621, :df=>#<Nyaplot::DataFrame:0xb7eda0f0 @name="13d1350d-58e8-47a6-b4f7-ba06f3f63a0c", @rows=[{:axis=>0, :val=>21.0, :name=>"CDK11A"}, {:axis=>4985012, :val=>1.0, :name=>"PARK7"}, {:axis=>9970024, :val=>10.0, :name=>"TNFRSF1B"}, {:axis=>14955036, :val=>0, :name=>""}, {:axis=>19940048, :val=>16.0, :name=>"PINK1"}, {:axis=>24925060, :val=>0, :name=>""}, {:axis=>29910072, :val=>0, :name=>""}, {:axis=>34895084, :val=>0, :name=>""}, {:axis=>39880096, :val=>1.0, :name=>"MPL"}, {:axis=>44865108, :val=>3.0, :name=>"MUTYH"}, {:axis=>49850120, :val=>0, :name=>""}, {:axis=>54835132, :val=>20.0, :name=>"USP24"}, {:axis=>59820144, :val=>0, :name=>""}, {:axis=>64805156, :val=>0, :name=>""}, {:axis=>69790168, :val=>0, :name=>""}, {:axis=>74775180, :val=>0, :name=>""}, {:axis=>79760192, :val=>0, :name=>""}, {:axis=>84745204, :val=>0, :name=>""}, {:axis=>89730216, :val=>0, :name=>""}, {:axis=>94715228, :val=>0, :name=>""}, {:axis=>99700240, :val=>0, :name=>""}, {:axis=>104685252, :val=>0, :name=>""}, {:axis=>109670264, :val=>0, :name=>""}, {:axis=>114655276, :val=>0, :name=>""}, {:axis=>119640288, :val=>0, :name=>""}, {:axis=>124625300, :val=>0, :name=>""}, {:axis=>129610312, :val=>0, :name=>""}, {:axis=>134595324, :val=>0, :name=>""}, {:axis=>139580336, :val=>0, :name=>""}, {:axis=>144565348, :val=>0, :name=>""}, {:axis=>149550360, :val=>0, :name=>""}, {:axis=>154535372, :val=>0, :name=>""}, {:axis=>159520384, :val=>0, :name=>""}, {:axis=>164505396, :val=>0, :name=>""}, {:axis=>169490408, :val=>0, :name=>""}, {:axis=>174475420, :val=>0, :name=>""}, {:axis=>179460432, :val=>29.0, :name=>"RNASEL"}, {:axis=>184445444, :val=>0, :name=>""}, {:axis=>189430456, :val=>0, :name=>""}, {:axis=>194415468, :val=>0, :name=>""}, {:axis=>199400480, :val=>0, :name=>""}, {:axis=>204385492, :val=>0, :name=>""}, {:axis=>209370504, :val=>0, :name=>""}, {:axis=>214355516, :val=>0, :name=>""}, {:axis=>219340528, :val=>26.0, :name=>"TLR5"}, {:axis=>224325540, :val=>9.0, :name=>"PARP1"}, {:axis=>229310552, :val=>0, :name=>""}, {:axis=>234295564, :val=>0, :name=>""}, {:axis=>239280576, :val=>0, :name=>""}, {:axis=>244265588, :val=>0, :name=>""}]>}, {:name=>"2", :size=>243199373, :df=>#<Nyaplot::DataFrame:0xb7ee331c @name="d73fba21-fa0c-4b3b-b2dc-3c1976b32053", @rows=[{:axis=>0, :val=>0, :name=>""}, {:axis=>4985012, :val=>0, :name=>""}, {:axis=>9970024, :val=>11.0, :name=>"ROCK2"}, {:axis=>14955036, :val=>0, :name=>""}, {:axis=>19940048, :val=>0, :name=>""}, {:axis=>24925060, :val=>0, :name=>""}, {:axis=>29910072, :val=>0, :name=>""}, {:axis=>34895084, :val=>0, :name=>""}, {:axis=>39880096, :val=>0, :name=>""}, {:axis=>44865108, :val=>5.0, :name=>"MSH6"}, {:axis=>49850120, :val=>0, :name=>""}, {:axis=>54835132, :val=>0, :name=>""}, {:axis=>59820144, :val=>0, :name=>""}, {:axis=>64805156, :val=>0, :name=>""}, {:axis=>69790168, :val=>0, :name=>""}, {:axis=>74775180, :val=>0, :name=>""}, {:axis=>79760192, :val=>0, :name=>""}, {:axis=>84745204, :val=>0, :name=>""}, {:axis=>89730216, :val=>0, :name=>""}, {:axis=>94715228, :val=>11.0, :name=>"INPP4A"}, {:axis=>99700240, :val=>0, :name=>""}, {:axis=>104685252, :val=>0, :name=>""}, {:axis=>109670264, :val=>0, :name=>""}, {:axis=>114655276, :val=>0, :name=>""}, {:axis=>119640288, :val=>1.0, :name=>"GLI2"}, {:axis=>124625300, :val=>0, :name=>""}, {:axis=>129610312, :val=>0, :name=>""}, {:axis=>134595324, :val=>0, :name=>""}, {:axis=>139580336, :val=>0, :name=>""}, {:axis=>144565348, :val=>0, :name=>""}, {:axis=>149550360, :val=>0, :name=>""}, {:axis=>154535372, :val=>0, :name=>""}, {:axis=>159520384, :val=>1.0, :name=>"DPP4"}, {:axis=>164505396, :val=>0, :name=>""}, {:axis=>169490408, :val=>2.0, :name=>"LRP2"}, {:axis=>174475420, :val=>0, :name=>""}, {:axis=>179460432, :val=>6.0, :name=>"FRZB"}, {:axis=>184445444, :val=>0, :name=>""}, {:axis=>189430456, :val=>0, :name=>""}, {:axis=>194415468, :val=>0, :name=>""}, {:axi ...

# %%
color = Nyaplot::Colors.qual
# Out:
# #<Nyaplot::Color:0xb84e5904 @source=["rgb(251,180,174)", "rgb(179,205,227)", "rgb(204,235,197)", "rgb(222,203,228)", "rgb(254,217,166)", "rgb(255,255,204)", "rgb(229,216,189)", "rgb(253,218,236)", "rgb(242,242,242)"]>

# %%
plot2 = Nyaplot::CircularPlot.new(df, :name, :df)
arc = plot2.add(1, :arc, :axis, :val)
arc.color(["rgb(56,108,176)"])
labels = plot2.add(2, :labels, :axis, :name)
labels.text_size("0.3em")
plot2.color(color)
plot2.text_size("0.5em")
plot2.text_color("#000")
plot2.show
# Out:
# "<div id='vis-d07bbbc3-1949-40aa-8a16-7f9b55f712f3'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"arc\",\"options\":{\"x\":\"axis\",\"y\":\"val\",\"range\":[0,76.0],\"layer\":1,\"color\":[\"rgb(56,108,176)\"]},\"data\":\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\"},{\"type\":\"labels\",\"options\":{\"x\":\"axis\",\"text\":\"name\",\"layer\":2,\"text_size\":\"0.3em\"},\"data\":\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\"}],\"options\":{\"zoom\":true,\"width\":800,\"height\":800,\"axis_extra_options\":{\"group_by\":\"name\",\"color\":[\"rgb(251,180,174)\",\"rgb(179,205,227)\",\"rgb(204,235,197)\",\"rgb(222,203,228)\",\"rgb(254,217,166)\",\"rgb(255,255,204)\",\"rgb(229,216,189)\",\"rgb(253,218,236)\",\"rgb(242,242,242)\"],\"text_size\":\"0.5em\",\"text_color\":\"#000\",\"inner_num\":0,\"outer_num\":3,\"df_id\":\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\",\"axis\":\"axis\"}},\"axis_extra_options\":{\"group_by\":\"name\",\"color\":[\"rgb(251,180,174)\",\"rgb(179,205,227)\",\"rgb(204,235,197)\",\"rgb(222,203,228)\",\"rgb(254,217,166)\",\"rgb(255,255,204)\",\"rgb(229,216,189)\",\"rgb(253,218,236)\",\"rgb(242,242,242)\"],\"text_size\":\"0.5em\",\"text_color\":\"#000\",\"inner_num\":0,\"outer_num\":3,\"df_id\":\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\",\"axis\":\"axis\"},\"extension\":\"Bionya\"}],\"data\":{\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\":[{\"name\":\"1\",\"size\":249250621,\"df\":[{\"axis\":0,\"val\":21.0,\"name\":\"CDK11A\"},{\"axis\":4985012,\"val\":1.0,\"name\":\"PARK7\"},{\"axis\":9970024,\"val\":10.0,\"name\":\"TNFRSF1B\"},{\"axis\":14955036,\"val\":0,\"name\":\"\"},{\"axis\":19940048,\"val\":16.0,\"name\":\"PINK1\"},{\"axis\":24925060,\"val\":0,\"name\":\"\"},{\"axis\":29910072,\"val\":0,\"name\":\"\"},{\"axis\":34895084,\"val\":0,\"name\":\"\"},{\"axis\":39880096,\"val\":1.0,\"name\":\"MPL\"},{\"axis\":44865108,\"val\":3.0,\"name\":\"MUTYH\"},{\"axis\":49850120,\"val\":0,\"name\":\"\"},{\"axis\":54835132,\"val\":20.0,\"name\":\"USP24\"},{\"axis\":59820144,\"val\":0,\"name\":\"\"},{\"axis\":64805156,\"val\":0,\"name\":\"\"},{\"axis\":69790168,\"val\":0,\"name\":\"\"},{\"axis\":74775180,\"val\":0,\"name\":\"\"},{\"axis\":79760192,\"val\":0,\"name\":\"\"},{\"axis\":84745204,\"val\":0,\"name\":\"\"},{\"axis\":89730216,\"val\":0,\"name\":\"\"},{\"axis\":94715228,\"val\":0,\"name\":\"\"},{\"axis\":99700240,\"val\":0,\"name\":\"\"},{\"axis\":104685252,\"val\":0,\"name\":\"\"},{\"axis\":109670264,\"val\":0,\"name\":\"\"},{\"axis\":114655276,\"val\":0,\"name\":\"\"},{\"axis\":119640288,\"val\":0,\"name\":\"\"},{\"axis\":124625300,\"val\":0,\"name\":\"\"},{\"axis\":129610312,\"val\":0,\"name\":\"\"},{\"axis\":134595324,\"val\":0,\"name\":\"\"},{\"axis\":139580336,\"val\":0,\"name\":\"\"},{\"axis\":144565348,\"val\":0,\"name\":\"\"},{\"axis\":149550360,\"val\":0,\"name\":\"\"},{\"axis\":154535372,\"val\":0,\"name\":\"\"},{\"axis\":159520384,\"val\":0,\"name\":\"\"},{\"axis\":164505396,\"val\":0,\"name\":\"\"},{\"axis\":169490408,\"val\":0,\"name\":\"\"},{\"axis\":174475420,\"val\":0,\"name\":\"\"},{\"axis\":179460432,\"val\":29.0,\"name\":\"RNASEL\"},{\"axis\":184445444,\"val\":0,\"name\":\"\"},{\"axis\":189430456,\"val\":0,\"name\":\"\"},{\"axis\":194415468,\"val\":0,\"name\":\"\"},{\"axis\":199400480,\"val\":0,\"name\":\"\"},{\"axis\":204385492,\"val\":0,\"name\":\"\"},{\"axis\":209370504,\"val\":0,\"name\":\"\"},{\"axis\":214355516,\"val\":0,\"name\":\"\"},{\"axis\":219340528,\"val\":26.0,\"name\":\"TLR5\"},{\"axis\":224325540,\"val\":9.0,\"name\":\"PARP1\"},{\"axis\":229310552,\"val\":0,\"name\":\"\"},{\"axis\":234295564,\"val\":0,\"name\":\"\"},{\"axis\":239280576,\"val\":0,\"name\":\"\"},{\"axis\":244265588,\"val\":0,\"name\":\"\"}]},{\"name\":\"2\",\"size\":243199373,\"df\":[{\"axis\":0,\"val\":0,\"name\":\"\"},{\"axis\":4985012,\"val\":0,\"name\":\"\"},{\"axis\":9970024,\"val\":11.0,\"name\":\"ROCK2\"},{\"axis\":14955036,\"val\":0,\"name\":\"\"},{\"axis\":1994004 ...

# %%
from=[]; to=[]
df.each_row do |row|
  chr_name = row[:name]
  axis = row[:df].axis.to_a
  2.times do |i|
    num = axis.sample
    from.push(chr_name + '.' + num.to_s)
    num = axis.sample
    to.push(chr_name + '.' + num.to_s)
  end
end
connector_df = Nyaplot::DataFrame.new({from: from.shuffle,to: to.shuffle})
connector_df
# Out:
# #<Nyaplot::DataFrame:0xb856873c @name="ca5cbbcf-e0c0-4170-a464-905c9243658f", @rows=[{:from=>"22.29910072", :to=>"22.39880096"}, {:from=>"10.109670264", :to=>"2.104685252"}, {:from=>"16.74775180", :to=>"10.74775180"}, {:from=>"9.4985012", :to=>"20.24925060"}, {:from=>"y.34895084", :to=>"2.204385492"}, {:from=>"4.64805156", :to=>"19.49850120"}, {:from=>"x.84745204", :to=>"8.0"}, {:from=>"15.14955036", :to=>"13.109670264"}, {:from=>"14.64805156", :to=>"16.64805156"}, {:from=>"4.29910072", :to=>"x.24925060"}, {:from=>"7.59820144", :to=>"18.19940048"}, {:from=>"2.64805156", :to=>"12.109670264"}, {:from=>"21.24925060", :to=>"7.139580336"}, {:from=>"13.79760192", :to=>"9.114655276"}, {:from=>"14.4985012", :to=>"14.4985012"}, {:from=>"10.104685252", :to=>"15.79760192"}, {:from=>"8.4985012", :to=>"3.129610312"}, {:from=>"19.29910072", :to=>"5.39880096"}, {:from=>"1.69790168", :to=>"21.29910072"}, {:from=>"20.54835132", :to=>"21.9970024"}, {:from=>"19.4985012", :to=>"13.104685252"}, {:from=>"11.109670264", :to=>"1.194415468"}, {:from=>"20.19940048", :to=>"20.4985012"}, {:from=>"22.4985012", :to=>"16.14955036"}, {:from=>"9.29910072", :to=>"6.14955036"}, {:from=>"13.64805156", :to=>"10.29910072"}, {:from=>"6.24925060", :to=>"14.54835132"}, {:from=>"2.9970024", :to=>"3.59820144"}, {:from=>"3.19940048", :to=>"18.49850120"}, {:from=>"17.54835132", :to=>"7.139580336"}, {:from=>"12.124625300", :to=>"1.84745204"}, {:from=>"6.79760192", :to=>"4.139580336"}, {:from=>"5.69790168", :to=>"x.39880096"}, {:from=>"1.179460432", :to=>"12.49850120"}, {:from=>"16.54835132", :to=>"8.4985012"}, {:from=>"18.0", :to=>"11.84745204"}, {:from=>"15.4985012", :to=>"y.4985012"}, {:from=>"17.19940048", :to=>"15.64805156"}, {:from=>"7.109670264", :to=>"6.79760192"}, {:from=>"3.154535372", :to=>"17.54835132"}, {:from=>"21.24925060", :to=>"11.9970024"}, {:from=>"x.64805156", :to=>"4.44865108"}, {:from=>"11.0", :to=>"17.39880096"}, {:from=>"12.94715228", :to=>"22.9970024"}, {:from=>"8.14955036", :to=>"9.129610312"}, {:from=>"5.139580336", :to=>"5.74775180"}, {:from=>"18.54835132", :to=>"y.14955036"}, {:from=>"y.49850120", :to=>"19.0"}]>

# %%
plot2.add_connector_with_df(connector_df, :from, :to)
plot2.show
# Out:
# "<div id='vis-ce4522df-6181-4ca2-80c1-66715c042c08'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"arc\",\"options\":{\"x\":\"axis\",\"y\":\"val\",\"range\":[0,76.0],\"layer\":1,\"color\":[\"rgb(56,108,176)\"]},\"data\":\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\"},{\"type\":\"labels\",\"options\":{\"x\":\"axis\",\"text\":\"name\",\"layer\":2,\"text_size\":\"0.3em\"},\"data\":\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\"},{\"type\":\"connector\",\"options\":{\"from\":\"from\",\"to\":\"to\"},\"data\":\"ca5cbbcf-e0c0-4170-a464-905c9243658f\"}],\"options\":{\"zoom\":true,\"width\":800,\"height\":800,\"axis_extra_options\":{\"group_by\":\"name\",\"color\":[\"rgb(251,180,174)\",\"rgb(179,205,227)\",\"rgb(204,235,197)\",\"rgb(222,203,228)\",\"rgb(254,217,166)\",\"rgb(255,255,204)\",\"rgb(229,216,189)\",\"rgb(253,218,236)\",\"rgb(242,242,242)\"],\"text_size\":\"0.5em\",\"text_color\":\"#000\",\"inner_num\":0,\"outer_num\":3,\"df_id\":\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\",\"axis\":\"axis\"}},\"axis_extra_options\":{\"group_by\":\"name\",\"color\":[\"rgb(251,180,174)\",\"rgb(179,205,227)\",\"rgb(204,235,197)\",\"rgb(222,203,228)\",\"rgb(254,217,166)\",\"rgb(255,255,204)\",\"rgb(229,216,189)\",\"rgb(253,218,236)\",\"rgb(242,242,242)\"],\"text_size\":\"0.5em\",\"text_color\":\"#000\",\"inner_num\":0,\"outer_num\":3,\"df_id\":\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\",\"axis\":\"axis\"},\"extension\":\"Bionya\"}],\"data\":{\"d88171ed-0fc2-4a47-8a38-9f2b7ef693bd\":[{\"name\":\"1\",\"size\":249250621,\"df\":[{\"axis\":0,\"val\":21.0,\"name\":\"CDK11A\"},{\"axis\":4985012,\"val\":1.0,\"name\":\"PARK7\"},{\"axis\":9970024,\"val\":10.0,\"name\":\"TNFRSF1B\"},{\"axis\":14955036,\"val\":0,\"name\":\"\"},{\"axis\":19940048,\"val\":16.0,\"name\":\"PINK1\"},{\"axis\":24925060,\"val\":0,\"name\":\"\"},{\"axis\":29910072,\"val\":0,\"name\":\"\"},{\"axis\":34895084,\"val\":0,\"name\":\"\"},{\"axis\":39880096,\"val\":1.0,\"name\":\"MPL\"},{\"axis\":44865108,\"val\":3.0,\"name\":\"MUTYH\"},{\"axis\":49850120,\"val\":0,\"name\":\"\"},{\"axis\":54835132,\"val\":20.0,\"name\":\"USP24\"},{\"axis\":59820144,\"val\":0,\"name\":\"\"},{\"axis\":64805156,\"val\":0,\"name\":\"\"},{\"axis\":69790168,\"val\":0,\"name\":\"\"},{\"axis\":74775180,\"val\":0,\"name\":\"\"},{\"axis\":79760192,\"val\":0,\"name\":\"\"},{\"axis\":84745204,\"val\":0,\"name\":\"\"},{\"axis\":89730216,\"val\":0,\"name\":\"\"},{\"axis\":94715228,\"val\":0,\"name\":\"\"},{\"axis\":99700240,\"val\":0,\"name\":\"\"},{\"axis\":104685252,\"val\":0,\"name\":\"\"},{\"axis\":109670264,\"val\":0,\"name\":\"\"},{\"axis\":114655276,\"val\":0,\"name\":\"\"},{\"axis\":119640288,\"val\":0,\"name\":\"\"},{\"axis\":124625300,\"val\":0,\"name\":\"\"},{\"axis\":129610312,\"val\":0,\"name\":\"\"},{\"axis\":134595324,\"val\":0,\"name\":\"\"},{\"axis\":139580336,\"val\":0,\"name\":\"\"},{\"axis\":144565348,\"val\":0,\"name\":\"\"},{\"axis\":149550360,\"val\":0,\"name\":\"\"},{\"axis\":154535372,\"val\":0,\"name\":\"\"},{\"axis\":159520384,\"val\":0,\"name\":\"\"},{\"axis\":164505396,\"val\":0,\"name\":\"\"},{\"axis\":169490408,\"val\":0,\"name\":\"\"},{\"axis\":174475420,\"val\":0,\"name\":\"\"},{\"axis\":179460432,\"val\":29.0,\"name\":\"RNASEL\"},{\"axis\":184445444,\"val\":0,\"name\":\"\"},{\"axis\":189430456,\"val\":0,\"name\":\"\"},{\"axis\":194415468,\"val\":0,\"name\":\"\"},{\"axis\":199400480,\"val\":0,\"name\":\"\"},{\"axis\":204385492,\"val\":0,\"name\":\"\"},{\"axis\":209370504,\"val\":0,\"name\":\"\"},{\"axis\":214355516,\"val\":0,\"name\":\"\"},{\"axis\":219340528,\"val\":26.0,\"name\":\"TLR5\"},{\"axis\":224325540,\"val\":9.0,\"name\":\"PARP1\"},{\"axis\":229310552,\"val\":0,\"name\":\"\"},{\"axis\":234295564,\"val\":0,\"name\":\"\"},{\"axis\":239280576,\"val\":0,\"name\":\"\"},{\"axis\":244265588,\"val\":0,\"name\":\"\"}]},{\"name\":\"2\",\"size\":243199373,\"df\":[{\"axis\":0,\"val\":0,\"name\":\"\"},{\"axis\":4985012,\"val\":0,\"name ...
