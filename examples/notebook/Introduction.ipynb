# %% [markdown]
# # Nyaplot Tutorial 4: Introduction of charts bundled with Nyaplot
#
# Several diagram types are bundled with Nyaplot and their usage is similar. This notebook is an introduction to them.

# %%
gem 'nyaplot', '0.1.5'
require 'nyaplot'
# Out:
# false

# %%
require 'distribution'

# RNGs used in the examples below.
rng = Random.new
normal_rng = Distribution::Normal.rng
# Out:
# #<Proc:0x007ff7d9883d48@/Users/agarie/.gem/ruby/2.2.0/gems/distribution-0.7.2/lib/distribution/normal/ruby.rb:17 (lambda)>

# %% [markdown]
# ## Bar chart
#
# What are these charts? In what situation we would use them?

# %%
plot = Nyaplot::Plot.new
plot.add(:bar, ['Persian', 'Maine Coon', 'American Shorthair'], [10, 20, 30])
plot.x_label("Species")
plot.y_label("Number")
plot.show
# Out:
# #<Nyaplot::Frame:0x007ff7d943f598 @properties={:panes=>[#<Nyaplot::Plot:0x007ff7d9444a98 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007ff7d943fbd8 @properties={:type=>:bar, :options=>{:x=>"data0", :y=>"data1"}, :data=>"8e01439c-a145-46c2-bf7d-037074a0ceef"}, @xrange=["Persian", "Maine Coon", "American Shorthair"], @yrange=[0, 30]>], :options=>{:x_label=>"Species", :y_label=>"Number", :width=>700, :xrange=>["Persian", "Maine Coon", "American Shorthair"], :yrange=>[0, 30]}}>], :data=>{"8e01439c-a145-46c2-bf7d-037074a0ceef"=>#<Nyaplot::DataFrame:0x007ff7d9444408 @name="8e01439c-a145-46c2-bf7d-037074a0ceef", @rows=[{:data0=>"Persian", :data1=>10}, {:data0=>"Maine Coon", :data1=>20}, {:data0=>"American Shorthair", :data1=>30}]>}, :extension=>[]}>

# %% [markdown]
# ## Line chart
#
# What are these charts? In what situation we would use them?

# %%
x = []
y = []
theta = 0.6
a = 1

while theta < 14 * Math::PI do
  x.push(a * Math::cos(theta) / theta)
  y.push(a * Math::sin(theta) / theta)
  theta += 0.1
end

plot = Nyaplot::Plot.new
plot.add(:line, x, y)
plot.show
# Out:
# #<Nyaplot::Frame:0x007ff7da499d80 @properties={:panes=>[#<Nyaplot::Plot:0x007ff7d9405b68 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007ff7da49a320 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1"}, :data=>"fbbe40e2-00f6-48d4-9797-5c565b0bf55a"}, @xrange=[-0.33650797881023503, 1.3755593581827972], @yrange=[-0.21722891503668823, 0.9410707889917257]>], :options=>{:zoom=>true, :width=>700, :xrange=>[-0.33650797881023503, 1.3755593581827972], :yrange=>[-0.21722891503668823, 0.9410707889917257]}}>], :data=>{"fbbe40e2-00f6-48d4-9797-5c565b0bf55a"=>#<Nyaplot::DataFrame:0x007ff7d9405410 @name="fbbe40e2-00f6-48d4-9797-5c565b0bf55a", @rows=[{:data0=>1.3755593581827972, :data1=>0.9410707889917257}, {:data0=>1.0926316961206979, :data1=>0.9203109817681301}, {:data0=>0.8708833866839569, :data1=>0.8966951136244035}, {:data0=>0.6906777425229608, :data1=>0.870363232919426}, {:data0=>0.54030230586814, :data1=>0.8414709848078965}, {:data0=>0.4123601103868887, :data1=>0.8101885091467594}, {:data0=>0.30196479539722804, :data1=>0.7766992383060219}, {:data0=>0.20576832971122103, :data1=>0.7411986041670715}, {:data0=>0.12140510207160057, :data1=>0.7038926642774715}, {:data0=>0.047158134445135114, :data1=>0.6649966577360362}, {:data0=>-0.018249701438305645, :data1=>0.6247335019009406}, {:data0=>-0.07579087899736768, :data1=>0.5833322414426284}, {:data0=>-0.12622338594060414, :data1=>0.5410264615989971}, {:data0=>-0.17015240361237047, :data1=>0.49805267773021794}, {:data0=>-0.20807341827357134, :data1=>0.45464871341284063}, {:data0=>-0.24040290695231323, :data1=>0.4110520793566063}, {:data0=>-0.26750050784333906, :data1=>0.36749836537254077}, {:data0=>-0.28968522664340196, :data1=>0.32421965746813897}, {:data0=>-0.30724738147551905, :data1=>0.28144299189631256}, {:data0=>-0.3204574462187736, :data1=>0.23938885764158221}, {:data0=>-0.32957259744959516, :data1=>0.19826975839287045}, {:data0=>-0.3348415340803931, :data1=>0.1582888445310477}, {:data0=>-0.33650797881023503, :data1=>0.11963862505567989}, {:data0=>-0.33481316039641046, :data1=>0.08249976869447621}, {:data0=>-0.32999749886681506, :data1=>0.04704000268662194}, {:data0=>-0.3223016613784771, :data1=>0.013413116913964239}, {:data0=>-0.31196711743586014, :data1=>-0.018241919821119182}, {:data0=>-0.29923629391177703, :data1=>-0.04780172549795451}, {:data0=>-0.28435240958219415, :data1=>-0.07515914765495083}, {:data0=>-0.26755905351165576, :data1=>-0.10022377933989181}, {:data0=>-0.24909956009281825, :data1=>-0.12292234535968162}, {:data0=>-0.2292162247865964, :data1=>-0.14319895700229582}, {:data0=>-0.20814939787221445, :data1=>-0.16101523445861063}, {:data0=>-0.18613648825644571, :data1=>-0.17635029722666024}, {:data0=>-0.16341090521590257, :data1=>-0.18920062382698227}, {:data0=>-0.14020096256908965, :data1=>-0.19957978318644173}, {:data0=>-0.11672876698588061, :data1=>-0.2075180410508544}, {:data0=>-0.09320910978604059, :data1=>-0.21306184575568723}, {:data0=>-0.06984837954054984, :data1=>-0.21627319861125366}, {:data0=>-0.04684351098461772, :data1=>-0.21722891503668823}, {:data0=>-0.024380984116316277, :data1=>-0.21601978339857925}, {:data0=>-0.0026358858431683937, :data1=>-0.21274962926895766}, {:data0=>0.018228954883217817, :data1=>-0.20753429350746688}, {:data0=>0.038063748861749805, :data1=>-0.20050053318863942}, {:data0=>0.05673243709264494, :data1=>-0.19178485493262787}, {:data0=>0.0741132828848978, :data1=>-0.18153229065249676}, {:data0=>0.09009935986545672, :data1=>-0.1698951261000298}, {:data0=>0.10459893135455828, :data1=>-0.15703159287243457}, {:data0=>0.11753571776715413, :data1=>-0.14310453473259072}, {:data0=>0.12884904987113782, :data1=>-0.12828005919461727}, {:data0=>0.13849390687682997, :data1=>-0.1127261853343437}, {:data0=>0.14644083944546632, :data1=>-0.09661149870134066}, {:data0=>0.1526757787829858, :data1=>-0.08010382403685547}, {:data0=>0.15719973402441265, :data1=>-0.06336892624241378}, {:data0=>0.16002838110839424, :data1=>-0.04656924969982187}, {:data0= ...

# %% [markdown]
# ## Scatter
#
# What are these charts? In what situation we would use them?
#
# In this example, we're...

# %%
line_x = []
line_y = []

sc_x = line_x # Just a reference to the same Array.
sc_y = []

a = 0.5
b = 3
noise = 1.5
x = 0

while x < 10
  line_x.push(x)
  line_y.push(a * x + b)
  sc_y.push(a * x + b + noise * (rnd.rand - 0.5))
  x = (x + 0.5).round(1)
end

plot = Nyaplot::Plot.new
sc = plot.add(:scatter, sc_x, sc_y)
line = plot.add(:line, line_x, line_y)
sc.color('#000')
sc.title('point')
line.title('line')
plot.legend(true)
plot.show
# Out:
# #<Nyaplot::Frame:0x007ff7d9882d58 @properties={:panes=>[#<Nyaplot::Plot:0x007ff7da2c3a38 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007ff7da2c18c8 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"#000", :title=>"point"}, :data=>"bbf2bd95-8b96-46fb-942e-d9d57e61908c"}, @xrange=[0, 9.5], @yrange=[2.8881046388879206, 7.540663465312795]>, #<Nyaplot::Diagram:0x007ff7d98833c0 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"line"}, :data=>"3ade3b04-7b73-4958-a31a-80e786c864ba"}, @xrange=[0, 9.5], @yrange=[3.0, 7.75]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 9.5], :yrange=>[2.8881046388879206, 7.75]}}>], :data=>{"bbf2bd95-8b96-46fb-942e-d9d57e61908c"=>#<Nyaplot::DataFrame:0x007ff7da2c3330 @name="bbf2bd95-8b96-46fb-942e-d9d57e61908c", @rows=[{:data0=>0, :data1=>2.8881046388879206}, {:data0=>0.5, :data1=>3.7758642607022748}, {:data0=>1.0, :data1=>3.877024549511433}, {:data0=>1.5, :data1=>3.1692070061088295}, {:data0=>2.0, :data1=>4.012077648282447}, {:data0=>2.5, :data1=>3.789537497518523}, {:data0=>3.0, :data1=>4.835828105751089}, {:data0=>3.5, :data1=>5.4676722427386135}, {:data0=>4.0, :data1=>4.428006717792423}, {:data0=>4.5, :data1=>5.351029060325851}, {:data0=>5.0, :data1=>5.472600867555615}, {:data0=>5.5, :data1=>6.148432032436612}, {:data0=>6.0, :data1=>5.591474403824402}, {:data0=>6.5, :data1=>5.509327104079212}, {:data0=>7.0, :data1=>6.201819962916812}, {:data0=>7.5, :data1=>6.7821476713452435}, {:data0=>8.0, :data1=>7.540663465312795}, {:data0=>8.5, :data1=>7.423531944262485}, {:data0=>9.0, :data1=>7.498320490123497}, {:data0=>9.5, :data1=>7.242384190247351}]>, "3ade3b04-7b73-4958-a31a-80e786c864ba"=>#<Nyaplot::DataFrame:0x007ff7da2c0c98 @name="3ade3b04-7b73-4958-a31a-80e786c864ba", @rows=[{:data0=>0, :data1=>3.0}, {:data0=>0.5, :data1=>3.25}, {:data0=>1.0, :data1=>3.5}, {:data0=>1.5, :data1=>3.75}, {:data0=>2.0, :data1=>4.0}, {:data0=>2.5, :data1=>4.25}, {:data0=>3.0, :data1=>4.5}, {:data0=>3.5, :data1=>4.75}, {:data0=>4.0, :data1=>5.0}, {:data0=>4.5, :data1=>5.25}, {:data0=>5.0, :data1=>5.5}, {:data0=>5.5, :data1=>5.75}, {:data0=>6.0, :data1=>6.0}, {:data0=>6.5, :data1=>6.25}, {:data0=>7.0, :data1=>6.5}, {:data0=>7.5, :data1=>6.75}, {:data0=>8.0, :data1=>7.0}, {:data0=>8.5, :data1=>7.25}, {:data0=>9.0, :data1=>7.5}, {:data0=>9.5, :data1=>7.75}]>}, :extension=>[]}>

# %% [markdown]
# ### Scatterplots with different shapes
#
# Let's use other shapes for the points in a scatterplot.
#
# **TODO**: We should have a list of available shapes somewhere in the docs.

# %%
sc.shape(["triangle-up"])
sc.color('#e13')
plot.show
# Out:
# #<Nyaplot::Frame:0x007ff7da481820 @properties={:panes=>[#<Nyaplot::Plot:0x007ff7da2c3a38 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007ff7da2c18c8 @properties={:type=>:scatter, :options=>{:x=>"data0", :y=>"data1", :color=>"#e13", :title=>"point", :shape=>["triangle-up"]}, :data=>"bbf2bd95-8b96-46fb-942e-d9d57e61908c"}, @xrange=[0, 9.5], @yrange=[2.8881046388879206, 7.540663465312795]>, #<Nyaplot::Diagram:0x007ff7d98833c0 @properties={:type=>:line, :options=>{:x=>"data0", :y=>"data1", :title=>"line"}, :data=>"3ade3b04-7b73-4958-a31a-80e786c864ba"}, @xrange=[0, 9.5], @yrange=[3.0, 7.75]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[0, 9.5], :yrange=>[2.8881046388879206, 7.75]}}>], :data=>{"bbf2bd95-8b96-46fb-942e-d9d57e61908c"=>#<Nyaplot::DataFrame:0x007ff7da2c3330 @name="bbf2bd95-8b96-46fb-942e-d9d57e61908c", @rows=[{:data0=>0, :data1=>2.8881046388879206}, {:data0=>0.5, :data1=>3.7758642607022748}, {:data0=>1.0, :data1=>3.877024549511433}, {:data0=>1.5, :data1=>3.1692070061088295}, {:data0=>2.0, :data1=>4.012077648282447}, {:data0=>2.5, :data1=>3.789537497518523}, {:data0=>3.0, :data1=>4.835828105751089}, {:data0=>3.5, :data1=>5.4676722427386135}, {:data0=>4.0, :data1=>4.428006717792423}, {:data0=>4.5, :data1=>5.351029060325851}, {:data0=>5.0, :data1=>5.472600867555615}, {:data0=>5.5, :data1=>6.148432032436612}, {:data0=>6.0, :data1=>5.591474403824402}, {:data0=>6.5, :data1=>5.509327104079212}, {:data0=>7.0, :data1=>6.201819962916812}, {:data0=>7.5, :data1=>6.7821476713452435}, {:data0=>8.0, :data1=>7.540663465312795}, {:data0=>8.5, :data1=>7.423531944262485}, {:data0=>9.0, :data1=>7.498320490123497}, {:data0=>9.5, :data1=>7.242384190247351}]>, "3ade3b04-7b73-4958-a31a-80e786c864ba"=>#<Nyaplot::DataFrame:0x007ff7da2c0c98 @name="3ade3b04-7b73-4958-a31a-80e786c864ba", @rows=[{:data0=>0, :data1=>3.0}, {:data0=>0.5, :data1=>3.25}, {:data0=>1.0, :data1=>3.5}, {:data0=>1.5, :data1=>3.75}, {:data0=>2.0, :data1=>4.0}, {:data0=>2.5, :data1=>4.25}, {:data0=>3.0, :data1=>4.5}, {:data0=>3.5, :data1=>4.75}, {:data0=>4.0, :data1=>5.0}, {:data0=>4.5, :data1=>5.25}, {:data0=>5.0, :data1=>5.5}, {:data0=>5.5, :data1=>5.75}, {:data0=>6.0, :data1=>6.0}, {:data0=>6.5, :data1=>6.25}, {:data0=>7.0, :data1=>6.5}, {:data0=>7.5, :data1=>6.75}, {:data0=>8.0, :data1=>7.0}, {:data0=>8.5, :data1=>7.25}, {:data0=>9.0, :data1=>7.5}, {:data0=>9.5, :data1=>7.75}]>}, :extension=>[]}>

# %% [markdown]
# ## Histogram
#
# What are these charts? In what situation we would use them?

# %%
arr = []

1000.times { arr.push(normal_rng.call) }

plot = Nyaplot::Plot.new
plot.add(:histogram, arr)
plot.yrange([0, 300])
plot.show
# Out:
# #<Nyaplot::Frame:0x007ff7d89ea098 @properties={:panes=>[#<Nyaplot::Plot:0x007ff7da41a918 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007ff7d89eabd8 @properties={:type=>:histogram, :options=>{:value=>"data0"}, :data=>"3be7f553-305a-49bc-98c0-b7c3cbf774b7"}, @xrange=[-3.289931813749032, 2.9783985577251464], @yrange=[0, 1000]>], :options=>{:yrange=>[0, 300], :width=>700, :xrange=>[-3.289931813749032, 2.9783985577251464]}}>], :data=>{"3be7f553-305a-49bc-98c0-b7c3cbf774b7"=>#<Nyaplot::DataFrame:0x007ff7da41a4b8 @name="3be7f553-305a-49bc-98c0-b7c3cbf774b7", @rows=[{:data0=>-0.5191363972963695}, {:data0=>0.011650654778292755}, {:data0=>-0.5067005155353581}, {:data0=>-0.1841615592980337}, {:data0=>-1.9088734266391998}, {:data0=>-2.0195973903045576}, {:data0=>0.3038065852838151}, {:data0=>0.6004698916735847}, {:data0=>-1.6273361807399507}, {:data0=>1.1286744188285827}, {:data0=>1.6276520879009377}, {:data0=>0.7248515826871988}, {:data0=>-0.0960820839139011}, {:data0=>-0.41544191422323296}, {:data0=>-0.22236864554799918}, {:data0=>-1.5827166888439632}, {:data0=>-0.3267521257515681}, {:data0=>-0.8064403360746586}, {:data0=>-0.3614594290213802}, {:data0=>-1.9928105839491168}, {:data0=>0.9522397808958502}, {:data0=>-1.0428055944608747}, {:data0=>-0.3353530724669313}, {:data0=>-1.5067855614473464}, {:data0=>-0.5877971190893091}, {:data0=>-0.32254878549689614}, {:data0=>-1.8934637879804626}, {:data0=>0.7040119448966389}, {:data0=>-0.7039092820064707}, {:data0=>0.19207787928117437}, {:data0=>1.5062597253519103}, {:data0=>-1.3447665544118168}, {:data0=>-2.228246106769015}, {:data0=>-0.5974182359981447}, {:data0=>-0.6276022801528837}, {:data0=>-0.6410953401303835}, {:data0=>-0.09463793435257213}, {:data0=>-0.33354683763875637}, {:data0=>1.421539357202397}, {:data0=>-1.9225676832922522}, {:data0=>2.484183698359876}, {:data0=>2.0099448693203867}, {:data0=>-0.5757164841489679}, {:data0=>0.5217392014415696}, {:data0=>0.2961776168853632}, {:data0=>-3.289931813749032}, {:data0=>2.6556068206113372}, {:data0=>-0.37726446717764345}, {:data0=>-0.49382058372680376}, {:data0=>2.09519611281803}, {:data0=>1.5058542783687134}, {:data0=>0.6260316326344374}, {:data0=>-1.2806967373484381}, {:data0=>0.3918676656394065}, {:data0=>-0.25675455162107913}, {:data0=>-0.2810650240727371}, {:data0=>1.073451545682898}, {:data0=>-0.14834716768758824}, {:data0=>2.3350150522826785}, {:data0=>1.0197751071808439}, {:data0=>-1.4290294047500984}, {:data0=>0.4263428890493514}, {:data0=>-0.5442675165482748}, {:data0=>-0.8240968056654346}, {:data0=>-1.4610100859658548}, {:data0=>1.6601386600515273}, {:data0=>0.7603421542496708}, {:data0=>0.3919892892362902}, {:data0=>-0.7280584944810858}, {:data0=>-1.222068802869371}, {:data0=>1.073657231073978}, {:data0=>-0.6224828972943554}, {:data0=>-0.08825107177065641}, {:data0=>0.4701242439559326}, {:data0=>0.4943227662332249}, {:data0=>-1.7846446189019929}, {:data0=>0.7075474879484644}, {:data0=>0.1269023920192473}, {:data0=>0.6097814687060066}, {:data0=>-0.963627106422304}, {:data0=>-0.19578704408321643}, {:data0=>0.8967246701266014}, {:data0=>-1.1029157511677987}, {:data0=>-0.45781750365976553}, {:data0=>0.26065235116924035}, {:data0=>-0.020426590256202755}, {:data0=>-0.5250394247640976}, {:data0=>1.0096862152219872}, {:data0=>-1.0520983764574072}, {:data0=>0.007617383718943398}, {:data0=>-0.11728930373410176}, {:data0=>-2.1939447445473963}, {:data0=>1.3475543365262865}, {:data0=>0.5829446595270106}, {:data0=>1.4246122690271037}, {:data0=>-0.807070078195948}, {:data0=>2.4244640766028795}, {:data0=>0.4097584487427571}, {:data0=>0.3713434830920278}, {:data0=>0.705379566860768}, {:data0=>0.6613660396622077}, {:data0=>-1.3252425468139162}, {:data0=>-0.02784044636946584}, {:data0=>0.16874556796109702}, {:data0=>0.32890620650138785}, {:data0=>0.6686644606887142}, {:data0=>1.8679551169785453}, {:data0=>1.8241464580690514}, {:data0=>-0.4332984758785243}, {:data0=>0.5361259423416342}, {:data0=>0.05912276982510483}, {:data0=>0.03300110659206994},  ...

# %% [markdown]
# ## Box plot
#
# What are these charts? In what situation we would use them?

# %%
arr2 = arr.map{ |x| x / 0.8 - 2}
arr3 = arr.map{ |x| x * 1.1 + 0.3}
arr4 = arr.map{ |x| x * 1.3 + 0.3}

plot4 = Nyaplot::Plot.new
plot4.add(:box, arr, arr2, arr3, arr4)
plot4.show
# Out:
# #<Nyaplot::Frame:0x007ff7d90d62f8 @properties={:panes=>[#<Nyaplot::Plot:0x007ff7d893ccb8 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007ff7d90dca68 @properties={:type=>:box, :options=>{:value=>["data0", "data1", "data2", "data3"]}, :data=>"f84101fe-9b19-4a69-b360-93b6ec8a7b29"}, @xrange=["data0", "data1", "data2", "data3"], @yrange=[-6.11241476718629, 4.171918125042691]>], :options=>{:width=>700, :xrange=>["data0", "data1", "data2", "data3"], :yrange=>[-6.11241476718629, 4.171918125042691]}}>], :data=>{"f84101fe-9b19-4a69-b360-93b6ec8a7b29"=>#<Nyaplot::DataFrame:0x007ff7d8937308 @name="f84101fe-9b19-4a69-b360-93b6ec8a7b29", @rows=[{:data0=>-0.5191363972963695, :data1=>-2.6489204966204616, :data2=>-0.27105003702600655, :data3=>-0.3748773164852804}, {:data0=>0.011650654778292755, :data1=>-1.985436681527134, :data2=>0.31281572025612203, :data3=>0.31514585121178057}, {:data0=>-0.5067005155353581, :data1=>-2.6333756444191976, :data2=>-0.257370567088894, :data3=>-0.35871067019596553}, {:data0=>-0.1841615592980337, :data1=>-2.230201949122542, :data2=>0.09742228477216289, :data3=>0.06058997291255616}, {:data0=>-1.9088734266391998, :data1=>-4.386091783298999, :data2=>-1.7997607693031197, :data3=>-2.1815354546309598}, {:data0=>-2.0195973903045576, :data1=>-4.524496737880697, :data2=>-1.9215571293350135, :data3=>-2.325476607395925}, {:data0=>0.3038065852838151, :data1=>-1.620241768395231, :data2=>0.6341872438121966, :data3=>0.6949485608689596}, {:data0=>0.6004698916735847, :data1=>-1.249412635408019, :data2=>0.9605168808409432, :data3=>1.08061085917566}, {:data0=>-1.6273361807399507, :data1=>-4.034170225924939, :data2=>-1.4900697988139457, :data3=>-1.8155370349619357}, {:data0=>1.1286744188285827, :data1=>-0.5891569764642717, :data2=>1.541541860711441, :data3=>1.7672767444771575}, {:data0=>1.6276520879009377, :data1=>0.034565109876171896, :data2=>2.0904172966910317, :data3=>2.415947714271219}, {:data0=>0.7248515826871988, :data1=>-1.0939355216410016, :data2=>1.0973367409559187, :data3=>1.2423070574933586}, {:data0=>-0.0960820839139011, :data1=>-2.1201026048923763, :data2=>0.19430970769470876, :data3=>0.17509329091192855}, {:data0=>-0.41544191422323296, :data1=>-2.519302392779041, :data2=>-0.15698610564555632, :data3=>-0.2400744884902029}, {:data0=>-0.22236864554799918, :data1=>-2.277960806934999, :data2=>0.05539448989720086, :data3=>0.01092076078760107}, {:data0=>-1.5827166888439632, :data1=>-3.978395861054954, :data2=>-1.4409883577283595, :data3=>-1.7575316954971523}, {:data0=>-0.3267521257515681, :data1=>-2.4084401571894603, :data2=>-0.05942733832672492, :data3=>-0.12477776347703856}, {:data0=>-0.8064403360746586, :data1=>-3.008050420093323, :data2=>-0.5870843696821246, :data3=>-0.7483724368970561}, {:data0=>-0.3614594290213802, :data1=>-2.451824286276725, :data2=>-0.09760537192351826, :data3=>-0.16989725772779424}, {:data0=>-1.9928105839491168, :data1=>-4.491013229936396, :data2=>-1.8920916423440286, :data3=>-2.290653759133852}, {:data0=>0.9522397808958502, :data1=>-0.8097002738801873, :data2=>1.3474637589854352, :data3=>1.5379117151646053}, {:data0=>-1.0428055944608747, :data1=>-3.3035069930760934, :data2=>-0.8470861539069623, :data3=>-1.055647272799137}, {:data0=>-0.3353530724669313, :data1=>-2.419191340583664, :data2=>-0.06888837971362449, :data3=>-0.13595899420701074}, {:data0=>-1.5067855614473464, :data1=>-3.883481951809183, :data2=>-1.3574641175920812, :data3=>-1.6588212298815503}, {:data0=>-0.5877971190893091, :data1=>-2.7347463988616365, :data2=>-0.34657683099824005, :data3=>-0.4641362548161018}, {:data0=>-0.32254878549689614, :data1=>-2.40318598187112, :data2=>-0.05480366404658582, :data3=>-0.11931342114596499}, {:data0=>-1.8934637879804626, :data1=>-4.366829734975578, :data2=>-1.782810166778509, :data3=>-2.161502924374602}, {:data0=>0.7040119448966389, :data1=>-1.1199850688792015, :data2=>1.0744131393863028, :data3=>1.2152155283656305}, {:data0=>-0.7039092820064707, :data1=>-2.8798866025080883, :data2=>-0.47430021020711793 ...

# %% [markdown]
# ## 2D Histogram
#
# What are these charts? In what situation we would use them?

# %%
x = []
y = []
fill = []

-5.step(5, 0.2) do |i|
  -5.step(5, 0.2) do |j|
    x.push(i)
    y.push(j)
      
    z = Math.sin(Math.sqrt(i * i + j * j)) / Math.sqrt(i * i + j * j)
    fill.push((z.nan? ? 0 : z))
  end
end

plot = Nyaplot::Plot.new
heatmap = plot.add(:heatmap, x, y, fill)

heatmap.stroke_color("#fff")
heatmap.stroke_width("0")
heatmap.width(0.2)
heatmap.height(0.2)

plot.legend(true)
plot.show
# Out:
# #<Nyaplot::Frame:0x007ff7d98a9368 @properties={:panes=>[#<Nyaplot::Plot:0x007ff7d9137d78 @properties={:diagrams=>[#<Nyaplot::Diagram:0x007ff7d98a9b60 @properties={:type=>:heatmap, :options=>{:x=>"data0", :y=>"data1", :fill=>"data2", :stroke_color=>"#fff", :stroke_width=>"0", :width=>0.2, :height=>0.2}, :data=>"152866cc-7a47-4c2d-ac84-1a8fee0a5a19"}, @xrange=[-5.0, 5.0], @yrange=[-5.0, 5.0]>], :options=>{:legend=>true, :zoom=>true, :width=>800, :xrange=>[-5.0, 5.0], :yrange=>[-5.0, 5.0]}}>], :data=>{"152866cc-7a47-4c2d-ac84-1a8fee0a5a19"=>#<Nyaplot::DataFrame:0x007ff7d9137378 @name="152866cc-7a47-4c2d-ac84-1a8fee0a5a19", @rows=[{:data0=>-5.0, :data1=>-5.0, :data2=>0.10024812527586709}, {:data0=>-5.0, :data1=>-4.8, :data2=>0.08707383663160287}, {:data0=>-5.0, :data1=>-4.6, :data2=>0.07197236146226313}, {:data0=>-5.0, :data1=>-4.4, :data2=>0.055292698693027754}, {:data0=>-5.0, :data1=>-4.2, :data2=>0.037404621449258525}, {:data0=>-5.0, :data1=>-4.0, :data2=>0.018686436816934687}, {:data0=>-5.0, :data1=>-3.8, :data2=>-0.0004869192903735675}, {:data0=>-5.0, :data1=>-3.5999999999999996, :data2=>-0.01975502585866488}, {:data0=>-5.0, :data1=>-3.4, :data2=>-0.038781973471461464}, {:data0=>-5.0, :data1=>-3.2, :data2=>-0.05726488313311144}, {:data0=>-5.0, :data1=>-3.0, :data2=>-0.07494068295407723}, {:data0=>-5.0, :data1=>-2.8, :data2=>-0.09159095408839148}, {:data0=>-5.0, :data1=>-2.5999999999999996, :data2=>-0.10704473897836123}, {:data0=>-5.0, :data1=>-2.4, :data2=>-0.12117928937050969}, {:data0=>-5.0, :data1=>-2.1999999999999997, :data2=>-0.13391881537228234}, {:data0=>-5.0, :data1=>-2.0, :data2=>-0.14523137672394124}, {:data0=>-5.0, :data1=>-1.7999999999999998, :data2=>-0.15512413034458303}, {:data0=>-5.0, :data1=>-1.5999999999999996, :data2=>-0.16363721125350594}, {:data0=>-5.0, :data1=>-1.4, :data2=>-0.17083657475247613}, {:data0=>-5.0, :data1=>-1.1999999999999997, :data2=>-0.17680616436357408}, {:data0=>-5.0, :data1=>-1.0, :data2=>-0.18163979110507836}, {:data0=>-5.0, :data1=>-0.7999999999999998, :data2=>-0.18543311452967862}, {:data0=>-5.0, :data1=>-0.5999999999999996, :data2=>-0.1882761044682014}, {:data0=>-5.0, :data1=>-0.39999999999999947, :data2=>-0.19024633518959477}, {:data0=>-5.0, :data1=>-0.1999999999999993, :data2=>-0.1914034219000563}, {:data0=>-5.0, :data1=>0.0, :data2=>-0.1917848549326277}, {:data0=>-5.0, :data1=>0.20000000000000018, :data2=>-0.1914034219000563}, {:data0=>-5.0, :data1=>0.40000000000000036, :data2=>-0.19024633518959477}, {:data0=>-5.0, :data1=>0.6000000000000005, :data2=>-0.1882761044682014}, {:data0=>-5.0, :data1=>0.8000000000000007, :data2=>-0.18543311452967862}, {:data0=>-5.0, :data1=>1.0, :data2=>-0.18163979110507836}, {:data0=>-5.0, :data1=>1.2000000000000002, :data2=>-0.17680616436357408}, {:data0=>-5.0, :data1=>1.4000000000000004, :data2=>-0.17083657475247613}, {:data0=>-5.0, :data1=>1.6000000000000005, :data2=>-0.16363721125350583}, {:data0=>-5.0, :data1=>1.8000000000000007, :data2=>-0.15512413034458303}, {:data0=>-5.0, :data1=>2.0, :data2=>-0.14523137672394124}, {:data0=>-5.0, :data1=>2.2, :data2=>-0.13391881537228234}, {:data0=>-5.0, :data1=>2.4000000000000004, :data2=>-0.12117928937050955}, {:data0=>-5.0, :data1=>2.6000000000000005, :data2=>-0.10704473897836123}, {:data0=>-5.0, :data1=>2.8000000000000007, :data2=>-0.09159095408839134}, {:data0=>-5.0, :data1=>3.0, :data2=>-0.07494068295407723}, {:data0=>-5.0, :data1=>3.200000000000001, :data2=>-0.05726488313311144}, {:data0=>-5.0, :data1=>3.4000000000000004, :data2=>-0.038781973471461464}, {:data0=>-5.0, :data1=>3.5999999999999996, :data2=>-0.01975502585866488}, {:data0=>-5.0, :data1=>3.8000000000000007, :data2=>-0.00048691929037342603}, {:data0=>-5.0, :data1=>4.0, :data2=>0.018686436816934687}, {:data0=>-5.0, :data1=>4.200000000000001, :data2=>0.03740462144925866}, {:data0=>-5.0, :data1=>4.4, :data2=>0.055292698693027754}, {:data0=>-5.0, :data1=>4.600000000000001, :data2=>0.07197236146226334}, {:data0=>-5.0, :data1=>4.800000000000001, :data ...
