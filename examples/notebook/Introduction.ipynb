# %%
require 'nyaplot'
# Out:
# true

# %% [markdown]
# # Single pane demo

# %%
plot = Nyaplot::Plot.new
bar = plot.add(:bar, ['Persian', 'Maine Coon', 'American Shorthair'], [10,20,30])
# Out:
# #<Nyaplot::Diagram:0xb98a4490 @properties={:type=>:bar, :options=>{:x=>"data0", :y=>"data1"}, :data=>"089654bc-3181-437d-974f-0fcda6fd7ca0"}, @xrange=["Persian", "Maine Coon", "American Shorthair"], @yrange=[0, 30]>

# %%
Nyaplot.init_iruby
# Out:
# "<script>\nif(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"http://d3js.org/d3.v3.min\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"https://rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\t};\n\n\n});\n}\n</script>\n"

# %%
plot.x_label("Species")
plot.y_label("Number")
plot.show
# Out:
# "<div id='vis-9c253627-6a30-47dc-a48d-f6f5a1cb8900'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"bar\",\"options\":{\"x\":\"data0\",\"y\":\"data1\"},\"data\":\"089654bc-3181-437d-974f-0fcda6fd7ca0\"}],\"options\":{\"x_label\":\"Species\",\"y_label\":\"Number\",\"width\":700,\"xrange\":[\"Persian\",\"Maine Coon\",\"American Shorthair\"],\"yrange\":[0,30]}}],\"data\":{\"089654bc-3181-437d-974f-0fcda6fd7ca0\":[{\"data0\":\"Persian\",\"data1\":10},{\"data0\":\"Maine Coon\",\"data1\":20},{\"data0\":\"American Shorthair\",\"data1\":30}]},\"extension\":[]}\n        Nyaplot.core.parse(model, '#vis-9c253627-6a30-47dc-a48d-f6f5a1cb8900');\n    };\n    if(window['Nyaplot']==undefined){\n        window.addEventListener('load_nyaplot', render, false);\n\treturn;\n    }\n    render();\n})();\n</script>\n"

# %%
x = []; y = []; theta = 0.6; a=1
while theta < 14*Math::PI do
  x.push(a*Math::cos(theta)/theta)
  y.push(a*Math::sin(theta)/theta)
  theta += 0.1
end
plot1 = Nyaplot::Plot.new
plot1.add(:line, x, y)
plot1.show
# Out:
# "<div id='vis-c94a5a02-91a6-45e4-b62a-7b4b797b8bbe'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"line\",\"options\":{\"x\":\"data0\",\"y\":\"data1\"},\"data\":\"13360edc-118a-47ff-a6a5-85682bd13bba\"}],\"options\":{\"zoom\":true,\"width\":700,\"xrange\":[-0.33650797881023503,1.3755593581827972],\"yrange\":[-0.21722891503668823,0.9410707889917257]}}],\"data\":{\"13360edc-118a-47ff-a6a5-85682bd13bba\":[{\"data0\":1.3755593581827972,\"data1\":0.9410707889917257},{\"data0\":1.0926316961206979,\"data1\":0.9203109817681301},{\"data0\":0.8708833866839569,\"data1\":0.8966951136244035},{\"data0\":0.6906777425229607,\"data1\":0.870363232919426},{\"data0\":0.5403023058681399,\"data1\":0.8414709848078965},{\"data0\":0.4123601103868887,\"data1\":0.8101885091467594},{\"data0\":0.30196479539722804,\"data1\":0.7766992383060219},{\"data0\":0.20576832971122103,\"data1\":0.7411986041670715},{\"data0\":0.12140510207160057,\"data1\":0.7038926642774715},{\"data0\":0.047158134445135114,\"data1\":0.6649966577360362},{\"data0\":-0.018249701438305645,\"data1\":0.6247335019009406},{\"data0\":-0.07579087899736768,\"data1\":0.5833322414426284},{\"data0\":-0.12622338594060414,\"data1\":0.5410264615989971},{\"data0\":-0.17015240361237047,\"data1\":0.4980526777302179},{\"data
></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"scatter\",\"options\":{\"x\":\"data0\",\"y\":\"data1\",\"color\":\"#000\",\"title\":\"point\"},\"data\":\"1dcbc923-2803-4156-be23-bc4df6b75a7b\"},{\"type\":\"line\",\"options\":{\"x\":\"data0\",\"y\":\"data1\",\"title\":\"line\"},\"data\":\"a323746b-209b-46c6-8f1f-92c666862fb2\"}],\"options\":{\"width\":800,\"legend\":true,\"zoom\":true,\"xrange\":[0,9.5],\"yrange\":[3.0,7.75]}}],\"data\":{\"1dcbc923-2803-4156-be23-bc4df6b75a7b\":[{\"data0\":0,\"data1\":3.238162891290301},{\"data0\":0.5,\"data1\":3.014717210108544},{\"data0\":1.0,\"data1\":3.5268217947868736},{\"data0\":1.5,\"data1\":4.4712034982171875},{\"data0\":2.0,\"data1\":4.59036610069965},{\"data0\":2.5,\"data1\":3.8317672259175186},{\"data0\":3.0,\"data1\":5.241379246620839},{\"data0\":3.5,\"data1\":4.449055353899653},{\"data0\":4.0,\"data1\":5.222295420042053},{\"data0\":4.5,\"data1\":5.5409288955369345},{\"data0\":5.0,\"data1\":5.850475014990617},{\"data0\":5.5,\"data1\":6.4999687031923274},{\"data0\":6.0,\"data1\":5.514355682350684},{\"data0\":6.5,\"data1\":6.0820561983115615},{\"data0\":7.0,\"data1\":6.100322374568124},{\"data0\":7.5,\"data1\":7.1408989339394076},{\"data0\":8.0,\"data1\":7.050640059606908},{\"data0\":8.5,\"data1\":7.095828953716326},{\"data0\":9.0,\"data1\":7.191883615646593},{\"data0\":9.5,\"data1\":7.469441707712187}],\"a323746b-209b-46c6-8f1f-92c666862fb2\":[{\"data0\":0,\"data1\":3.0},{\"data0\":0.5,\"data1\":3.25},{\"data0\":1.0,\"data1\":3.5},{\"data0\":1.5,\"data1\":3.75},{\"data0\":2.0,\"data1\":4.0},{\"data0\":2.5,\"data1\":4.25},{\"data0\":3.0,\"data1\":4.5},{\"data0\":3.5,\"data1\":4.75},{\"data0\":4.0,\"data1\":5.0},{\"data0\":4.5,\"data1\":5.25},{\"data0\":5.0,\"data1\":5.5},{\"data0\":5.5,\"data1\":5.75},{\"data0\":6.0,\"data1\":6.0},{\"data0\":6.5,\"data1\":6.25},{\"data0\":7.0,\"data1\":6.5},{\"data0\":7.5,\"data1\":6.75},{\"data0\":8.0,\"data1\":7.0},{\"data0\":8.5,\"data1\":7.25},{\"data0\":9.0,\"data1\":7.5},{\"data0\":9.5,\"data1\":7.75}]},\"extension\":[]}\n        Nyaplot.core.parse(model, '#vis-d3ba330f-b927-42a9-a41e-8e5d15a1a766');\n    };\n    if(window['Nyaplot']==undefined){\n        window.addEventListener('load_nyaplot', render, false);\n\treturn;\n    }\n    render();\n})();\n</script>\n"

# %%
require 'distribution'
rng = Distribution::Normal.rng
arr = []
1000.times {arr.push(rng.call)}
plot3 = Nyaplot::Plot.new
plot3.add(:histogram, arr)
plot3.yrange([0,300])
plot3.show
# Out:
# "<div id='vis-9e4258f4-657c-4311-bc57-d071ce6c2ea3'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\
":0.26940155042209396},{\"data0\":0.7592126402147621,\"data1\":0.7592126402147621,\"data2\":0.7592126402147621},{\"data0\":-0.2979147756640318,\"data1\":-0.2979147756640318,\"data2\":-0.2979147756640318},{\"data0\":-2.0873859510190327,\"data1\":-2.0873859510190327,\"data2\":-2.0873859510190327},{\"data0\":0.4374103554022084,\"data1\":0.4374103554022084,\"data2\":0.4374103554022084},{\"data0\":0.7951300047470918,\"data1\":0.7951300047470918,\"data2\":0.7951300047470918},{\"data0\":-2.308655599196144,\"data1\":-2.308655599196144,\"data2\":-2.308655599196144},{\"data0\":-1.0534143490769818,\"data1\":-1.0534143490769818,\"data2\":-1.0534143490769818},{\"data0\":-0.409977829036488,\"data1\":-0.409977829036488,\"data2\":-0.409977829036488},{\"data0\":1.1504608858262813,\"data1\":1.1504608858262813,\"data2\":1.1504608858262813},{\"data0\":1.0483689508041747,\"data1\":1.0483689508041747,\"data2\":1.0483689508041747},{\"data0\":0.7030114893217733,\"data1\":0.7030114893217733,\"data2\":0.7030114893217733},{\"data0\":0.006684709340660984,\"data1\":0.006684709340660984,\"data2\":0.006684709340660984},{\"data0\":-1.147246932361976,\"data1\":-1.147246932361976,\"data2\":-1.147246932361976},{\"data0\":0.240158971994382,\"data1\":0.240158971994382,\"data2\":0.240158971994382},{\"data0\":0.6190694671454257,\"data1\":0.6190694671454257,\"data2\":0.6190694671454257},{\"data0\":0.3539851969743892,\"data1\":0.3539851969743892,\"data2\":0.3539851969743892},{\"data0\":-1.6251072285257497,\"data1\":-1.6251072285257497,\"data2\":-1.6251072285257497},{\"data0\":-0.2759114420393477,\"data1\":-0.2759114420393477,\"data2\":-0.2759114420393477},{\"data0\":-0.1404129405106667,\"data1\":-0.1404129405106667,\"data2\":-0.1404129405106667},{\"data0\":-0.60 ...

# %% [markdown]
# # Multiple panes demo

# %% [markdown]
# First, fetch data from local storage.

# %%
path = File.expand_path("../data/first.tab", __FILE__)
df = Nyaplot::DataFrame.from_csv(path, sep="\t")
# Out:
# #<Nyaplot::DataFrame:0xb9f60c34 @name="b0c16f55-e0dd-40bf-9795-cf4ccace477f", @rows=[{"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.019230769230769232, "SET2"=>0.0, "SET3"=>0.48214285714285715, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.4782608695652174}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.42592592592592593, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.375, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>G", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.525, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.1935483870967742, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.4666666666666667, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.08333333333333333, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.5161290322580645, "SET3.1"=>0.0}, {"mutation"=>"G>T", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.4444444444444444, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>G", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.4}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.03333333333333333, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.42857142857142855, "SET3.1"=>0.0}, {"mutation"=>"A>C", "BLOOD"=>0.0, "SET1"=>0.6153846153846154, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5925925925925926, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.32, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.4230769230769231, "SET3.1"=>0.0}, {"mutation"=>"T>A", "BLOOD"=>0.0, "SET1"=>0.525, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5277777777777778, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.42857142857142855, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6666666666666666, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.5, "SET3.1"=>0.03225806451612903}, {"mutation"=>"T>C", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.3793103448275862}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.45714285714285713, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.46875}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5142857142857142, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.43478260869565216}, {"mutation"=>"G>C", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6857142857142857, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.45652173913043476, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.43478260869565216, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.09803921568627451, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.37142857142857144, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>T", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.52, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>A", "BLOOD"=>0.0, "SET1"=>0.5769230769230769, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.4782608695652174, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>G", "BLOOD"=>0.0, "SET1"=>0.43859649122807015, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5142857142857142, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>C", "BLOOD"=>0.0, "SET1"=>0.5806451612903226, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6341463414634146, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>C", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.40476190476190477, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.14705882352941177, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.5813953488372093, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.45714285714285713, "SET3.1"=>0.0 ...

# %% [markdown]
# Now I want to plot **SET1** column, but it contains many zero cells. Then filter them out.

# %%
df.filter! {|row| row['SET1'] != 0.0}
df
# Out:
# #<Nyaplot::DataFrame:0xb9f60c34 @name="b0c16f55-e0dd-40bf-9795-cf4ccace477f", @rows=[{"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.019230769230769232, "SET2"=>0.0, "SET3"=>0.48214285714285715, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.4782608695652174}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.42592592592592593, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.375, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>C", "BLOOD"=>0.0, "SET1"=>0.6153846153846154, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5925925925925926, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>A", "BLOOD"=>0.0, "SET1"=>0.525, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5277777777777778, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.42857142857142855, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6666666666666666, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.45652173913043476, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.43478260869565216, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.09803921568627451, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.37142857142857144, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>A", "BLOOD"=>0.0, "SET1"=>0.5769230769230769, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.4782608695652174, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>G", "BLOOD"=>0.0, "SET1"=>0.43859649122807015, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5142857142857142, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>C", "BLOOD"=>0.0, "SET1"=>0.5806451612903226, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6341463414634146, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.014705882352941176, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.41935483870967744}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.6666666666666666, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.532258064516129, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5227272727272727, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.5652173913043478, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.3870967741935484, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.42857142857142855, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.3333333333333333, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.4888888888888889, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.43243243243243246, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.01818181818181818, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.43478260869565216}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.45098039215686275, "SET2"=>0.03225806451612903, "SET3"=>0.0, "SET1.2"=>0.5882352941176471, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>T", "BLOOD"=>0.0, "SET1"=>0.5172413793103449, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.43333333333333335, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>C", "BLOOD"=>0.0, "SET1"=>0.04878048780487805, "SET2"=>0.0, "SET3"=>0.019230769230769232, "SET1.2"=>0.6060606060606061, "SET2.1"=>0.5662650602409639, "SET3.1"=>0.6296296296296297}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.4375, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.4782608695652174, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.4642857142857143, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>G", "BLOOD"=>0.0, "SET1"=>0.66, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5185185185185185, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>T", "BLOOD"=>0.0, "SET1"=>0.018518518518518517, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5833333333333334, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.45, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.35714285714285715, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.49230769230769234, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5161290322580645, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>C", "BLOOD"=>0.0, "S ...

# %% [markdown]
# Next prepare instance of Nyaplot::Plot as usual. Nyaplot::Plot.filter is a method for adding 'filter box' to the plot.

# %%
plot4=Nyaplot::Plot.new
plot4.add_with_df(df, :histogram, 'SET1')
plot4.configure do
  height(400)
  x_label('PNR')
  y_label('Frequency')
  filter({target:'x'})
  yrange([0,130])
end

plot5=Nyaplot::Plot.new
plot5.add_with_df(df, :bar, 'mutation')
plot5.configure do
  height(400)
  x_label('Mutation types')
  y_label('Frequency')
  yrange([0,100])
end
# Out:
# [0, 100]

# %% [markdown]
# Then create an instance of Nyaplot::Frame. It can hold multiple plots in it, and it helps them to interact with each other.

# %%
frame = Nyaplot::Frame.new
frame.add(plot4)
frame.add(plot5)
frame.show
# Out:
# "<div id='vis-a5c4737d-635b-4811-9238-3d38c0035ab8'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"histogram\",\"options\":{\"value\":\"SET1\"},\"data\":\"b0c16f55-e0dd-40bf-9795-cf4ccace477f\"}],\"options\":{\"height\":400,\"x_label\":\"PNR\",\"y_label\":\"Frequency\",\"yrange\":[0,130],\"width\":700,\"xrange\":[0,0.6956521739130435]},\"filter\":{\"target\":\"x\"}},{\"diagrams\":[{\"type\":\"bar\",\"options\":{\"value\":\"mutation\"},\"data\":\"b0c16f55-e0dd-40bf-9795-cf4ccace477f\"}],\"options\":{\"height\":400,\"x_label\":\"Mutation types\",\"y_label\":\"Frequency\",\"yrange\":[0,100],\"width\":700,\"xrange\":[\"G>A\",\"C>T\",\"A>C\",\"T>A\",\"A>G\",\"T>C\",\"C>A\",\"A>T\",\"T>G\",\"G>T\",\"G>C\",\"C>G\"]}}],\"data\":{\"b0c16f55-e0dd-40bf-9795-cf4ccace477f\":[{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.019230769230769232,\"SET2\":0.0,\"SET3\":0.48214285714285715,\"SET1.2\":0.0,\"SET2.1\":0.0,\"SET3.1\":0.4782608695652174},{\"mutation\":\"C>T\",\"BLOOD\":0.0,\"SET1\":0.42592592592592593,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.375,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"A>C\",\"BLOOD\":0.0,\"SET1\":0.6153846153846154,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5925925925925926,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"T>A\",\"BLOOD\":0.0,\"SET1\":0.525,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5277777777777778,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>T\",\"BLOOD\":0.0,\"SET1\":0.42857142857142855,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.6666666666666666,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.45652173913043476,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.43478260869565216,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>T\",\"BLOOD\":0.0,\"SET1\":0.09803921568627451,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.37142857142857144,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"T>A\",\"BLOOD\":0.0,\"SET1\":0.5769230769230769,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.4782608695652174,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"A>G\",\"BLOOD\":0.0,\"SET1\":0.43859649122807015,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5142857142857142,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"T>C\",\"BLOOD\":0.0,\"SET1\":0.5806451612903226,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.6341463414634146,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.014705882352941176,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.0,\"SET2.1\":0.0,\"SET3.1\":0.41935483870967744},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.6666666666666666,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>T\",\"BLOOD\":0.0,\"SET1\":0.532258064516129,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5227272727272727,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.5652173913043478,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.3870967741935484,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.42857142857142855,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.3333333333333333,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>A\",\"BLOOD\":0.0,\"SET1\":0.4888888888888889,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.43243243243243246,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>A\",\"BLOOD\":0.0,\"SET1\":0.01818181818181818,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.0,\"SET2.1\":0.0,\"SET3.1\":0.43478260869565216},{\"mutation\":\"C>A\",\"BLOOD\":0.0,\"SET1\":0.45098039215686275,\"SET2\":0.03225806451612903,\"SET3\":0.0,\"SET1.2\":0.5882352941176471,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"A>T\",\"BLOOD\":0.0,\"SET1\":0.5172413793103449,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.43333333333333335,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"T>C\",\"BLOOD\":0.0,\"SET1\":0.04878048780487805,\"SET2\":0.0,\"SET3\":0.019230769230769232,\"SET1.2\":0.6060606060606061,\"SET2.1\":0.5662650602409639,\"SET3.1\":0.6296296296296297},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.4375,\"SET2\":0.0,\"SET3\":0.0 ...
