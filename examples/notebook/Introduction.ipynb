# %%
require 'nyaplot'
# Out:
# true

# %% [markdown]
# # Single pane demo

# %%
plot = Nyaplot::Plot.new
bar = plot.add(:bar, ['Persian', 'Maine Coon', 'American Shorthair'], [10,20,30])
# Out:
# #<Nyaplot::Diagram:0xb8da5184 @properties={:type=>:bar, :options=>{:x=>"data0", :y=>"data1"}, :data=>"f49bb788-8b52-4c81-a5de-e487e0e246ed"}, @xrange=["Persian", "Maine Coon", "American Shorthair"], @yrange=[0, 30]>

# %%
Nyaplot.init_iruby
# Out:
# "<script>\nif(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"http://d3js.org/d3.v3.min\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"https://rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\t};\n\n\n});\n}\n</script>\n"

# %%
plot.x_label("Species")
plot.y_label("Number")
plot.show
# Out:
# "<div id='vis-05681ecb-9ba3-4b22-9d72-43ee6ea88d9b'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"bar\",\"options\":{\"x\":\"data0\",\"y\":\"data1\"},\"data\":\"f49bb788-8b52-4c81-a5de-e487e0e246ed\"}],\"options\":{\"x_label\":\"Species\",\"y_label\":\"Number\",\"xrange\":[\"Persian\",\"Maine Coon\",\"American Shorthair\"],\"yrange\":[0,30]}}],\"data\":{\"f49bb788-8b52-4c81-a5de-e487e0e246ed\":[{\"data0\":\"Persian\",\"data1\":10},{\"data0\":\"Maine Coon\",\"data1\":20},{\"data0\":\"American Shorthair\",\"data1\":30}]},\"extension\":[]}\n        Nyaplot.core.parse(model, '#vis-05681ecb-9ba3-4b22-9d72-43ee6ea88d9b');\n    };\n    if(window['Nyaplot']==undefined){\n        window.addEventListener('load_nyaplot', render, false);\n\treturn;\n    }\n    render();\n})();\n</script>\n"

# %%
x = []; y = []; theta = 0.6; a=1
while theta < 14*Math::PI do
  x.push(a*Math::cos(theta)/theta)
  y.push(a*Math::sin(theta)/theta)
  theta += 0.1
end
plot1 = Nyaplot::Plot.new
plot1.add(:line, x, y)
plot1.zoom(true)
plot1.show
# Out:
# "<div id='vis-4141a303-e6a4-4dd7-a44c-be6e7e085479'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"line\",\"options\":{\"x\":\"data0\",\"y\":\"data1\"},\"data\":\"f92716e2-27a3-421a-bf7d-f58e821c20eb\"}],\"options\":{\"zoom\":true,\"xrange\":[-0.33650797881023503,1.3755593581827972],\"yrange\":[-0.21722891503668823,0.9410707889917257]}}],\"data\":{\"f92716e2-27a3-421a-bf7d-f58e821c20eb\":[{\"data0\":1.3755593581827972,\"data1\":0.9410707889917257},{\"data0\":1.0926316961206979,\"data1\":0.9203109817681301},{\"data0\":0.8708833866839569,\"data1\":0.8966951136244035},{\"data0\":0.6906777425229607,\"data1\":0.870363232919426},{\"data0\":0.5403023058681399,\"data1\":0.8414709848078965},{\"data0\":0.4123601103868887,\"data1\":0.8101885091467594},{\"data0\":0.30196479539722804,\"data1\":0.7766992383060219},{\"data0\":0.20576832971122103,\"data1\":0.7411986041670715},{\"data0\":0.12140510207160057,\"data1\":0.7038926642774715},{\"data0\":0.047158134445135114,\"data1\":0.6649966577360362},{\"data0\":-0.018249701438305645,\"data1\":0.6247335019009406},{\"data0\":-0.07579087899736768,\"data1\":0.5833322414426284},{\"data0\":-0.12622338594060414,\"data1\":0.5410264615989971},{\"data0\":-0.17015240361237047,\"data1\":0.4980526777302179},{\"data0\":-0.20807341827357134,\"data1\":0.45464871341284063},{\"data0\":-0.24040290695231323,\"data1\":0.4110520793566063},{\"data0\":-0.2675005078433391,\"data1\":0.36749836537254077},{\"data0\":-0.28968522664340196,\"data1\":0.3242196574681389},{\"data0\":-0.30724738147551905,\"data1\":0.2814429918963125},{\"data0\":-0.3204574462187736,\"data1\":0.23938885764158221},{\"data0\":-0.32957259744959516,\"data1\":0.19826975839287045},{\"data0\":-0.3348415340803931,\"data1\":0.1582888445310477},{\"data0\":-0.33650797881023503,\"data1\":0.11963862505567989},{\"data0\":-0.33481316039641046,\"data1\":0.08249976869447621},{\"data0\":-0.32999749886681506,\"data1\":0.04704000268662195},{\"data0\":-0.3223016613784771,\"data1\":0.013413116913964239},{\"data0\":-0.31196711743586014,\"data1\":-0.018241919821119185},{\"data0\":-0.29923629391177703,\"data1\":-0.04780172549795451},{\"data0\":-0.28435240958219415,\"data1\":-0.07515914765495083},{\"data0\":-0.26755905351165576,\"data1\":-0.10022377933989181},{\"data0\":-0.24909956009281825,\"data1\":-0.12292234535968162},{\"data0\":-0.2292162247865964,\"data1\":-0.14319895700229582},{\"data0\":-0.20814939787221448,\"data1\":-0.16101523445861063},{\"data0\":-0.18613648825644571,\"data1\":-0.17635029722666024},{\"data0\":-0.16341090521590257,\"data1\":-0.18920062382698227},{\"data0\":-0.14020096256908965,\"data1\":-0.19957978318644173},{\"data0\":-0.1167287669858806,\"data1\":-0.2075180410508544},{\"data0\":-0.09320910978604059,\"data1\":-0.21306184575568723},{\"data0\":-0.06984837954054984,\"data1\":-0.21627319861125363},{\"data0\":-0.04684351098461771,\"data1\":-0.21722891503668823},{\"data0\":-0.024380984116316277,\"data1\":-0.21601978339857925},{\"data0\":-0.0026358858431683933,\"data1\":-0.21274962926895766},{\"data0\":0.018228954883217817,\"data1\":-0.20753429350746688},{\"data0\":0.03806374886174981,\"data1\":-0.20050053318863942},{\"data0\":0.05673243709264494,\"data1\":-0.19178485493262787},{\"data0\":0.0741132828848978,\"data1\":-0.18153229065249676},{\"data0\":0.09009935986545672,\"data1\":-0.1698951261000298},{\"data0\":0.10459893135455828,\"data1\":-0.15703159287243457},{\"data0\":0.11753571776715413,\"data1\":-0.14310453473259072},{\"data0\":0.12884904987113782,\"data1\":-0.12828005919461727},{\"data0\":0.13849390687682997,\"data1\":-0.1127261853343437},{\"data0\":0.14644083944546632,\"data1\":-0.09661149870134066},{\"data0\":0.15267577878298577,\"data1\":-0.08010382403685547},{\"data0\":0.15719973402441265,\"data1\":-0.06336892624241378},{\"data0\":0.16002838110839424,\"data1\":-0.04656924969982187},{\"data0\":0.1611915472856696,\"data1\":-0.029862705618377262},{\"data0\":0.16073259629406 ...

# %%
sc_y=[]; line_x=sc_x=[]; line_y=[]; a=0.5; b=3; noise=1.5; x=0
rnd = Random.new
while x<10
  line_x.push(x)
  line_y.push(a*x+b)
  sc_y.push(a*x+b+noise*(rnd.rand-0.5))
  x=(x+0.5).round(1)
end
plot2 = Nyaplot::Plot.new
sc = plot2.add(:scatter, sc_x, sc_y)
line = plot2.add(:line, line_x, line_y)
sc.color('#000')
sc.title('point')
line.title('line')
plot2.width(800)
plot2.zoom(true)
plot2.legend(true)
plot2.show
# Out:
# "<div id='vis-cfdf2361-7848-4dea-834f-ea1316f60750'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"scatter\",\"options\":{\"x\":\"data0\",\"y\":\"data1\",\"color\":\"#000\",\"title\":\"point\"},\"data\":\"775acd03-91c3-4789-a827-af0c6fe35fc2\"},{\"type\":\"line\",\"options\":{\"x\":\"data0\",\"y\":\"data1\",\"title\":\"line\"},\"data\":\"4c8b478e-dfe0-45f6-a124-2562f0a3debe\"}],\"options\":{\"width\":800,\"zoom\":true,\"legend\":true,\"xrange\":[0,9.5],\"yrange\":[3.0,8.382972816726786]}}],\"data\":{\"775acd03-91c3-4789-a827-af0c6fe35fc2\":[{\"data0\":0,\"data1\":3.3660187724884074},{\"data0\":0.5,\"data1\":3.5070396786051177},{\"data0\":1.0,\"data1\":3.9010314251158675},{\"data0\":1.5,\"data1\":3.309126317262188},{\"data0\":2.0,\"data1\":4.4005099476684615},{\"data0\":2.5,\"data1\":4.410343565083048},{\"data0\":3.0,\"data1\":4.478361496481716},{\"data0\":3.5,\"data1\":4.481871533930491},{\"data0\":4.0,\"data1\":5.695813141423251},{\"data0\":4.5,\"data1\":4.875131193861208},{\"data0\":5.0,\"data1\":5.051710096370391},{\"data0\":5.5,\"data1\":5.752832946550704},{\"data0\":6.0,\"data1\":6.04132006204248},{\"data0\":6.5,\"data1\":5.7497107669718375},{\"data0\":7.0,\"data1\":5.754316448658761},{\"data0\":7.5,\"data1\":6.692964435912602},{\"data0\":8.0,\"data1\":7.688752829855424},{\"data0\":8.5,\"data1\":7.200881772878652},{\"data0\":9.0,\"data1\":7.531980201118003},{\"data0\":9.5,\"data1\":8.382972816726786}],\"4c8b478e-dfe0-45f6-a124-2562f0a3debe\":[{\"data0\":0,\"data1\":3.0},{\"data0\":0.5,\"data1\":3.25},{\"data0\":1.0,\"data1\":3.5},{\"data0\":1.5,\"data1\":3.75},{\"data0\":2.0,\"data1\":4.0},{\"data0\":2.5,\"data1\":4.25},{\"data0\":3.0,\"data1\":4.5},{\"data0\":3.5,\"data1\":4.75},{\"data0\":4.0,\"data1\":5.0},{\"data0\":4.5,\"data1\":5.25},{\"data0\":5.0,\"data1\":5.5},{\"data0\":5.5,\"data1\":5.75},{\"data0\":6.0,\"data1\":6.0},{\"data0\":6.5,\"data1\":6.25},{\"data0\":7.0,\"data1\":6.5},{\"data0\":7.5,\"data1\":6.75},{\"data0\":8.0,\"data1\":7.0},{\"data0\":8.5,\"data1\":7.25},{\"data0\":9.0,\"data1\":7.5},{\"data0\":9.5,\"data1\":7.75}]},\"extension\":[]}\n        Nyaplot.core.parse(model, '#vis-cfdf2361-7848-4dea-834f-ea1316f60750');\n    };\n    if(window['Nyaplot']==undefined){\n        window.addEventListener('load_nyaplot', render, false);\n\treturn;\n    }\n    render();\n})();\n</script>\n"

# %%
require 'distribution'
rng = Distribution::Normal.rng
arr = []
1000.times {arr.push(rng.call)}
plot3 = Nyaplot::Plot.new
plot3.add(:histogram, arr)
plot3.yrange([0,300])
plot3.show
# Out:
# "<div id='vis-ff987300-27c0-4ecc-b178-5064489ca36b'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"histogram\",\"options\":{\"value\":\"data0\"},\"data\":\"78ebf742-45d3-4fca-9ead-3f28c97fab63\"}],\"options\":{\"yrange\":[0,300],\"xrange\":[-3.5985271325062778,3.082019913395051]}}],\"data\":{\"78ebf742-45d3-4fca-9ead-3f28c97fab63\":[{\"data0\":0.7634958995439473},{\"data0\":1.2779809177507708},{\"data0\":1.3857760540654935},{\"data0\":-0.2646850212266379},{\"data0\":-0.418763599870362},{\"data0\":0.06792129351497524},{\"data0\":-0.5913362580807043},{\"data0\":-1.2584605706700396},{\"data0\":0.31635003282179575},{\"data0\":0.45282694077099434},{\"data0\":-2.5883736375890667},{\"data0\":1.1329804862210262},{\"data0\":-0.8704036998560578},{\"data0\":-0.4891258414481485},{\"data0\":-0.061078596026145855},{\"data0\":0.49654398824554824},{\"data0\":-0.577328606744661},{\"data0\":-1.5028860711367846},{\"data0\":-0.9988958257216127},{\"data0\":-0.45678099788543},{\"data0\":1.0431098147451998},{\"data0\":-2.4115941763499484},{\"data0\":-1.220643323884526},{\"data0\":0.9669588485702839},{\"data0\":-0.958738882963804},{\"data0\":-1.123199791057436},{\"data0\":0.7133267610649487},{\"data0\":1.3552992061303517},{\"data0\":1.5406971940560732},{\"data0\":-0.6898616328712562},{\"data0\":1.7880602579358966},{\"data0\":-1.0404583888263177},{\"data0\":-0.6441950846435954},{\"data0\":0.688926961795592},{\"data0\":0.44075495606247694},{\"data0\":0.050517418479874586},{\"data0\":-1.048569223606733},{\"data0\":0.05366256091341449},{\"data0\":-0.9218109128600923},{\"data0\":0.5733220730154488},{\"data0\":0.44449997270171937},{\"data0\":-0.3966833085563021},{\"data0\":1.127597684479372},{\"data0\":0.3679072031207522},{\"data0\":-0.12475451406835068},{\"data0\":-0.7133654423051458},{\"data0\":-1.1781912456087376},{\"data0\":1.1586701581966128},{\"data0\":-1.5856388680992912},{\"data0\":-0.8508803722728736},{\"data0\":-0.3188863310003565},{\"data0\":-0.6095692980429899},{\"data0\":0.1844655496067269},{\"data0\":0.6245664190946161},{\"data0\":1.239780495849696},{\"data0\":-1.592003920211431},{\"data0\":0.2296562174603893},{\"data0\":-0.4688524386874935},{\"data0\":-1.350150549283707},{\"data0\":0.8755935523937997},{\"data0\":-0.29598479307631287},{\"data0\":0.3201727583928446},{\"data0\":0.21034100152877144},{\"data0\":2.8253425145233244},{\"data0\":-0.9469277627459239},{\"data0\":0.12932339769171414},{\"data0\":-0.9514340871482141},{\"data0\":-0.8200595136441428},{\"data0\":-0.2929454815262327},{\"data0\":-0.7405614272403116},{\"data0\":-0.6634740167942251},{\"data0\":-0.5254323908450945},{\"data0\":0.5177733031908797},{\"data0\":-1.8188756952560898},{\"data0\":-0.08902593323443804},{\"data0\":-0.03913280973696099},{\"data0\":0.49652044257572653},{\"data0\":1.8172949799898275},{\"data0\":0.34036891732286156},{\"data0\":-1.2993361833514907},{\"data0\":0.24769371798489515},{\"data0\":0.44997522268921586},{\"data0\":0.30789645506602564},{\"data0\":-1.4044675922044336},{\"data0\":0.7352658401453652},{\"data0\":2.4238719485743285},{\"data0\":-0.5956138029167245},{\"data0\":-0.1468387739555235},{\"data0\":-0.1808787265814695},{\"data0\":-0.2764147799950717},{\"data0\":0.6636008961546074},{\"data0\":-1.3151565791061197},{\"data0\":-0.9436174937551166},{\"data0\":0.14814219277538584},{\"data0\":-1.270384863368626},{\"data0\":-0.6131456560809042},{\"data0\":-1.1167749658182589},{\"data0\":-1.3137634672568095},{\"data0\":1.3327677699567202},{\"data0\":-0.19935326617685897},{\"data0\":0.22685763740299983},{\"data0\":0.5881433977845266},{\"data0\":-0.405139458589732},{\"data0\":0.1545567945128648},{\"data0\":-0.9235436282413855},{\"data0\":0.9221851422153041},{\"data0\":0.34752547039995446},{\"data0\":1.0449945041682653},{\"data0\":-0.37888955430843857},{\"data0\":-0.02448036543576016},{\"data0\":0.696901750441244},{\"data0\":-0.5223008080940633},{\"data0\":-0.8376531185246345},{\"data0\":1.6 ...

# %%
plot4 = Nyaplot::Plot.new
plot4.add(:box, arr, arr, arr)
plot4.show
# Out:
# "<div id='vis-d06770bd-f856-40bf-8e7a-d947ca5475a8'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"box\",\"options\":{\"value\":[\"data0\",\"data1\",\"data2\"]},\"data\":\"c44524e3-89eb-45fa-9f6b-7f1e46bf22f0\"}],\"options\":{\"xrange\":[\"data0\",\"data1\",\"data2\"],\"yrange\":[-3.5985271325062778,3.082019913395051]}}],\"data\":{\"c44524e3-89eb-45fa-9f6b-7f1e46bf22f0\":[{\"data0\":0.7634958995439473,\"data1\":0.7634958995439473,\"data2\":0.7634958995439473},{\"data0\":1.2779809177507708,\"data1\":1.2779809177507708,\"data2\":1.2779809177507708},{\"data0\":1.3857760540654935,\"data1\":1.3857760540654935,\"data2\":1.3857760540654935},{\"data0\":-0.2646850212266379,\"data1\":-0.2646850212266379,\"data2\":-0.2646850212266379},{\"data0\":-0.418763599870362,\"data1\":-0.418763599870362,\"data2\":-0.418763599870362},{\"data0\":0.06792129351497524,\"data1\":0.06792129351497524,\"data2\":0.06792129351497524},{\"data0\":-0.5913362580807043,\"data1\":-0.5913362580807043,\"data2\":-0.5913362580807043},{\"data0\":-1.2584605706700396,\"data1\":-1.2584605706700396,\"data2\":-1.2584605706700396},{\"data0\":0.31635003282179575,\"data1\":0.31635003282179575,\"data2\":0.31635003282179575},{\"data0\":0.45282694077099434,\"data1\":0.45282694077099434,\"data2\":0.45282694077099434},{\"data0\":-2.5883736375890667,\"data1\":-2.5883736375890667,\"data2\":-2.5883736375890667},{\"data0\":1.1329804862210262,\"data1\":1.1329804862210262,\"data2\":1.1329804862210262},{\"data0\":-0.8704036998560578,\"data1\":-0.8704036998560578,\"data2\":-0.8704036998560578},{\"data0\":-0.4891258414481485,\"data1\":-0.4891258414481485,\"data2\":-0.4891258414481485},{\"data0\":-0.061078596026145855,\"data1\":-0.061078596026145855,\"data2\":-0.061078596026145855},{\"data0\":0.49654398824554824,\"data1\":0.49654398824554824,\"data2\":0.49654398824554824},{\"data0\":-0.577328606744661,\"data1\":-0.577328606744661,\"data2\":-0.577328606744661},{\"data0\":-1.5028860711367846,\"data1\":-1.5028860711367846,\"data2\":-1.5028860711367846},{\"data0\":-0.9988958257216127,\"data1\":-0.9988958257216127,\"data2\":-0.9988958257216127},{\"data0\":-0.45678099788543,\"data1\":-0.45678099788543,\"data2\":-0.45678099788543},{\"data0\":1.0431098147451998,\"data1\":1.0431098147451998,\"data2\":1.0431098147451998},{\"data0\":-2.4115941763499484,\"data1\":-2.4115941763499484,\"data2\":-2.4115941763499484},{\"data0\":-1.220643323884526,\"data1\":-1.220643323884526,\"data2\":-1.220643323884526},{\"data0\":0.9669588485702839,\"data1\":0.9669588485702839,\"data2\":0.9669588485702839},{\"data0\":-0.958738882963804,\"data1\":-0.958738882963804,\"data2\":-0.958738882963804},{\"data0\":-1.123199791057436,\"data1\":-1.123199791057436,\"data2\":-1.123199791057436},{\"data0\":0.7133267610649487,\"data1\":0.7133267610649487,\"data2\":0.7133267610649487},{\"data0\":1.3552992061303517,\"data1\":1.3552992061303517,\"data2\":1.3552992061303517},{\"data0\":1.5406971940560732,\"data1\":1.5406971940560732,\"data2\":1.5406971940560732},{\"data0\":-0.6898616328712562,\"data1\":-0.6898616328712562,\"data2\":-0.6898616328712562},{\"data0\":1.7880602579358966,\"data1\":1.7880602579358966,\"data2\":1.7880602579358966},{\"data0\":-1.0404583888263177,\"data1\":-1.0404583888263177,\"data2\":-1.0404583888263177},{\"data0\":-0.6441950846435954,\"data1\":-0.6441950846435954,\"data2\":-0.6441950846435954},{\"data0\":0.688926961795592,\"data1\":0.688926961795592,\"data2\":0.688926961795592},{\"data0\":0.44075495606247694,\"data1\":0.44075495606247694,\"data2\":0.44075495606247694},{\"data0\":0.050517418479874586,\"data1\":0.050517418479874586,\"data2\":0.050517418479874586},{\"data0\":-1.048569223606733,\"data1\":-1.048569223606733,\"data2\":-1.048569223606733},{\"data0\":0.05366256091341449,\"data1\":0.05366256091341449,\"data2\":0.05366256091341449},{\"data0\":-0.9218109128600923,\"data1\":-0.9218109128600923,\"data2\":-0.9218109128600923},{\"data0\":0.5 ...

# %% [markdown]
# # Multiple panes demo

# %% [markdown]
# First, fetch data from local storage.

# %%
path = File.expand_path("../data/first.tab", __FILE__)
df = Nyaplot::DataFrame.from_csv(path, sep="\t")
# Out:
# #<Nyaplot::DataFrame:0xb947d394 @name="79b6e965-ded6-4405-b556-5f358a3af1e3", @rows=[{"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.019230769230769232, "SET2"=>0.0, "SET3"=>0.48214285714285715, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.4782608695652174}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.42592592592592593, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.375, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>G", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.525, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.1935483870967742, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.4666666666666667, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.08333333333333333, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.5161290322580645, "SET3.1"=>0.0}, {"mutation"=>"G>T", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.4444444444444444, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>G", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.4}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.03333333333333333, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.42857142857142855, "SET3.1"=>0.0}, {"mutation"=>"A>C", "BLOOD"=>0.0, "SET1"=>0.6153846153846154, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5925925925925926, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.32, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.4230769230769231, "SET3.1"=>0.0}, {"mutation"=>"T>A", "BLOOD"=>0.0, "SET1"=>0.525, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5277777777777778, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.42857142857142855, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6666666666666666, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.5, "SET3.1"=>0.03225806451612903}, {"mutation"=>"T>C", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.3793103448275862}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.45714285714285713, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.46875}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5142857142857142, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.43478260869565216}, {"mutation"=>"G>C", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6857142857142857, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.45652173913043476, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.43478260869565216, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.09803921568627451, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.37142857142857144, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>T", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.52, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>A", "BLOOD"=>0.0, "SET1"=>0.5769230769230769, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.4782608695652174, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>G", "BLOOD"=>0.0, "SET1"=>0.43859649122807015, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5142857142857142, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>C", "BLOOD"=>0.0, "SET1"=>0.5806451612903226, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6341463414634146, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>C", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.40476190476190477, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.14705882352941177, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.5813953488372093, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.0, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.45714285714285713, "SET3.1"=>0.0 ...

# %% [markdown]
# Now I want to plot **SET1** column, but it contains many zero cells. Then filter them out.

# %%
df.filter! {|row| row['SET1'] != 0.0}
df
# Out:
# #<Nyaplot::DataFrame:0xb947d394 @name="79b6e965-ded6-4405-b556-5f358a3af1e3", @rows=[{"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.019230769230769232, "SET2"=>0.0, "SET3"=>0.48214285714285715, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.4782608695652174}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.42592592592592593, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.375, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>C", "BLOOD"=>0.0, "SET1"=>0.6153846153846154, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5925925925925926, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>A", "BLOOD"=>0.0, "SET1"=>0.525, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5277777777777778, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.42857142857142855, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6666666666666666, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.45652173913043476, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.43478260869565216, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.09803921568627451, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.37142857142857144, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>A", "BLOOD"=>0.0, "SET1"=>0.5769230769230769, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.4782608695652174, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>G", "BLOOD"=>0.0, "SET1"=>0.43859649122807015, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5142857142857142, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>C", "BLOOD"=>0.0, "SET1"=>0.5806451612903226, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.6341463414634146, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.014705882352941176, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.41935483870967744}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.6666666666666666, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>T", "BLOOD"=>0.0, "SET1"=>0.532258064516129, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5227272727272727, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.5652173913043478, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.3870967741935484, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.42857142857142855, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.3333333333333333, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.4888888888888889, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.43243243243243246, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.01818181818181818, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.0, "SET2.1"=>0.0, "SET3.1"=>0.43478260869565216}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.45098039215686275, "SET2"=>0.03225806451612903, "SET3"=>0.0, "SET1.2"=>0.5882352941176471, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>T", "BLOOD"=>0.0, "SET1"=>0.5172413793103449, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.43333333333333335, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>C", "BLOOD"=>0.0, "SET1"=>0.04878048780487805, "SET2"=>0.0, "SET3"=>0.019230769230769232, "SET1.2"=>0.6060606060606061, "SET2.1"=>0.5662650602409639, "SET3.1"=>0.6296296296296297}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.4375, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.4782608695652174, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.4642857142857143, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"T>G", "BLOOD"=>0.0, "SET1"=>0.66, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5185185185185185, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>T", "BLOOD"=>0.0, "SET1"=>0.018518518518518517, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5833333333333334, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"G>A", "BLOOD"=>0.0, "SET1"=>0.45, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.35714285714285715, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"C>A", "BLOOD"=>0.0, "SET1"=>0.49230769230769234, "SET2"=>0.0, "SET3"=>0.0, "SET1.2"=>0.5161290322580645, "SET2.1"=>0.0, "SET3.1"=>0.0}, {"mutation"=>"A>C", "BLOOD"=>0.0, "S ...

# %% [markdown]
# Next prepare instance of Nyaplot::Plot as usual. Nyaplot::Plot.filter is a method for adding 'filter box' to the plot.

# %%
plot4=Nyaplot::Plot.new
plot4.add_with_df(df, :histogram, 'SET1')
plot4.configure do
  height(400)
  x_label('PNR')
  y_label('Frequency')
  filter({target:'x'})
  yrange([0,130])
end

plot5=Nyaplot::Plot.new
plot5.add_with_df(df, :bar, 'mutation')
plot5.configure do
  height(400)
  x_label('Mutation types')
  y_label('Frequency')
  yrange([0,100])
end
# Out:
# [0, 100]

# %% [markdown]
# Then create an instance of Nyaplot::Frame. It can hold multiple plots in it, and it helps them to interact with each other.

# %%
frame = Nyaplot::Frame.new
frame.add(plot4)
frame.add(plot5)
frame.show
# Out:
# "<div id='vis-2a33600c-dea4-4402-9d62-fa237c2817cd'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"histogram\",\"options\":{\"value\":\"SET1\"},\"data\":\"79b6e965-ded6-4405-b556-5f358a3af1e3\"}],\"options\":{\"height\":400,\"x_label\":\"PNR\",\"y_label\":\"Frequency\",\"yrange\":[0,130],\"xrange\":[0,0.6956521739130435]},\"filter\":{\"target\":\"x\"}},{\"diagrams\":[{\"type\":\"bar\",\"options\":{\"value\":\"mutation\"},\"data\":\"79b6e965-ded6-4405-b556-5f358a3af1e3\"}],\"options\":{\"height\":400,\"x_label\":\"Mutation types\",\"y_label\":\"Frequency\",\"yrange\":[0,100],\"xrange\":[\"G>A\",\"C>T\",\"A>C\",\"T>A\",\"A>G\",\"T>C\",\"C>A\",\"A>T\",\"T>G\",\"G>T\",\"G>C\",\"C>G\"]}}],\"data\":{\"79b6e965-ded6-4405-b556-5f358a3af1e3\":[{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.019230769230769232,\"SET2\":0.0,\"SET3\":0.48214285714285715,\"SET1.2\":0.0,\"SET2.1\":0.0,\"SET3.1\":0.4782608695652174},{\"mutation\":\"C>T\",\"BLOOD\":0.0,\"SET1\":0.42592592592592593,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.375,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"A>C\",\"BLOOD\":0.0,\"SET1\":0.6153846153846154,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5925925925925926,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"T>A\",\"BLOOD\":0.0,\"SET1\":0.525,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5277777777777778,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>T\",\"BLOOD\":0.0,\"SET1\":0.42857142857142855,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.6666666666666666,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.45652173913043476,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.43478260869565216,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>T\",\"BLOOD\":0.0,\"SET1\":0.09803921568627451,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.37142857142857144,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"T>A\",\"BLOOD\":0.0,\"SET1\":0.5769230769230769,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.4782608695652174,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"A>G\",\"BLOOD\":0.0,\"SET1\":0.43859649122807015,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5142857142857142,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"T>C\",\"BLOOD\":0.0,\"SET1\":0.5806451612903226,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.6341463414634146,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.014705882352941176,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.0,\"SET2.1\":0.0,\"SET3.1\":0.41935483870967744},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.6666666666666666,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>T\",\"BLOOD\":0.0,\"SET1\":0.532258064516129,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5227272727272727,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.5652173913043478,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.3870967741935484,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.42857142857142855,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.3333333333333333,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>A\",\"BLOOD\":0.0,\"SET1\":0.4888888888888889,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.43243243243243246,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"C>A\",\"BLOOD\":0.0,\"SET1\":0.01818181818181818,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.0,\"SET2.1\":0.0,\"SET3.1\":0.43478260869565216},{\"mutation\":\"C>A\",\"BLOOD\":0.0,\"SET1\":0.45098039215686275,\"SET2\":0.03225806451612903,\"SET3\":0.0,\"SET1.2\":0.5882352941176471,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"A>T\",\"BLOOD\":0.0,\"SET1\":0.5172413793103449,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.43333333333333335,\"SET2.1\":0.0,\"SET3.1\":0.0},{\"mutation\":\"T>C\",\"BLOOD\":0.0,\"SET1\":0.04878048780487805,\"SET2\":0.0,\"SET3\":0.019230769230769232,\"SET1.2\":0.6060606060606061,\"SET2.1\":0.5662650602409639,\"SET3.1\":0.6296296296296297},{\"mutation\":\"G>A\",\"BLOOD\":0.0,\"SET1\":0.4375,\"SET2\":0.0,\"SET3\":0.0,\"SET1.2\":0.5,\"SET2.1\":0 ...
