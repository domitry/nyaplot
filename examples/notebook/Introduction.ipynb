# %%
require 'nyaplot'
# Out:
# false

# %%
df = Nyaplot::DataFrame.new({a:[1,2,3], b:[10,8,9]})
# Out:
# #<Nyaplot::DataFrame:0xb89d5310 @name="e1ed0ba1-489a-46e2-b25b-d531d2afa9cd", @rows=[{:a=>1, :b=>10}, {:a=>2, :b=>8}, {:a=>3, :b=>9}]>

# %%
plot = Nyaplot::Plot.new
bar = plot.add(:bar, ['nya1', 'nya2', 'nya3'], [10,20,30])
# Out:
# #<Nyaplot::Diagram:0xb8827054 @properties={:type=>:bar, :data=>"638cc5b5-9869-45ce-9def-a5b5e48c15c1", :options=>{:x=>"x", :y=>"y"}}, @xrange=["nya1", "nya2", "nya3"], @yrange=[0, 30]>

# %%
Nyaplot.init_iruby
# Out:
# "<script>if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\n\td3: 'http://d3js.org/d3.v3.min'\n    };\n\n    require.config({paths: path});\n\n    require(['d3'], function(d3){\n\twindow['d3'] = d3;\n\tconsole.log('Finished loading d3.js');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"https://rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\t};\n    });\n}\n</script>"

# %%
plot.show
# Out:
# "<div id='vis-cfc82d8c-8059-44fb-ad05-2c83408c363d'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"bar\",\"data\":\"638cc5b5-9869-45ce-9def-a5b5e48c15c1\",\"options\":{\"x\":\"x\",\"y\":\"y\"}}],\"options\":{\"xrange\":[\"nya1\",\"nya2\",\"nya3\"],\"yrange\":[0,30]}}],\"data\":{\"500ee22e-f9fd-4154-a823-e44fa5e60c92\":[{\"x\":\"nya1\",\"y\":10},{\"x\":\"nya2\",\"y\":20},{\"x\":\"nya3\",\"y\":30}],\"9eb7ded4-144d-46f1-88bb-0dd77e14c7b6\":[{\"x\":29.850124958340775,\"y\":2.9950024994048445},{\"x\":4.126678074548392,\"y\":2.823212366975177},{\"x\":1.2370803311606653,\"y\":2.430565527440278},{\"x\":-0.05474910431491652,\"y\":1.8742005057028222},{\"x\":-0.7212087208569393,\"y\":1.2331562380698196},{\"x\":-0.9887177923487853,\"y\":0.5948092751786125},{\"x\":-0.9669049841354317,\"y\":0.040239350741894025}],\"638cc5b5-9869-45ce-9def-a5b5e48c15c1\":[{\"x\":\"nya1\",\"y\":10},{\"x\":\"nya2\",\"y\":20},{\"x\":\"nya3\",\"y\":30}]}}\n        Nyaplot.core.parse(model, '#vis-cfc82d8c-8059-44fb-ad05-2c83408c363d');\n    };\n    if(window['Nyaplot']==undefined){\n        window.addEventListener('load_nyaplot', render, false);\n\treturn;\n    }\n    render();\n})();\n</script>\n"

# %%
x = []; y = []; theta = 0.1; a=1
while theta < 10*Math::PI do
  x.push((a*Math::cos(theta))/theta)
  y.push((a*Math::sin(theta))/theta)
  theta += 0.1
end
plot1 = Nyaplot::Plot.new
plot1.add(:line, x, y)
plot1.show
# Out:
# "<div id='vis-f041772c-df26-40f9-95a6-9c331c1a189a'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\
{\"x\":-0.9899924966004452,\"y\":0.14112000805986585},{\"x\":-0.9669049841354314,\"y\":0.040239350741892714},{\"x\":-0.9359013523075805,\"y\":-0.05472575946335756},{\"x\":-0.897708881735331,\"y\":-0.14340517649386353},{\"x\":-0.8530572287465824,\"y\":-0.22547744296485248},{\"x\":-0.8026771605349673,\"y\":-0.30067133801967544},{\"x\":-0.7472986802784548,\"y\":-0.3687670360790448},{\"x\":-0.6876486743597892,\"y\":-0.4295968710068875},{\"x\":-0.6244481936166435,\"y\":-0.4830457033758319},{\"x\":-0.5584094647693372,\"y\":-0.5290508916799808},{\"x\":-0.49023271564770776,\"y\":-0.5676018714809469},{\"x\":-0.42060288770726895,\"y\":-0.5987393495593253},{\"x\":-0.3501863009576418,\"y\":-0.6225541231525632},{\"x\":-0.2796273293581218,\"y\":-0.6391855372670617},{\"x\":-0.20954513862164953,\"y\":-0.6488195958337608},{\"x\":-0.14053053295385315,\"y\":-0.6516867451100646},{\"x\":-0.07 ...

# %%
plot2 = Nyaplot::Plot.new
plot2.add(:scatter, [0,1,2], [10,20,30])
plot2.show
# Out:
# "<div id='vis-4f80222f-8687-4e9a-a921-11d3a2059af4'></div>\n<script>\n(function(){\n    var render = function(){\n        var model = {\"panes\":[{\"diagrams\":[{\"type\":\"scatter\",\"data\":\"16c0d18f-9207-4eff-a1c0-8d0bda12658f\",\"options\":{\"x\":\"x\",\"y\":\"y\"}}],\"options\":{\"xrange\":[0,2],\"yrange\":[10,30]}}],\"data\":{\"500ee22e-f9fd-4154-a823-e44fa5e60c92\":[{\"x\":\"nya1\",\"y\":10},{\"x\":\"nya2\",\"y\":20},{\"x\":\"nya3\",\"y\":30}],\"9eb7ded4-144d-46f1-88bb-0dd77e14c7b6\":[{\"x\":29.850124958340775,\"y\":2.9950024994048445},{\"x\":4.126678074548392,\"y\":2.823212366975177},{\"x\":1.2370803311606653,\"y\":2.430565527440278},{\"x\":-0.05474910431491652,\"y\":1.8742005057028222},{\"x\":-0.7212087208569393,\"y\":1.2331562380698196},{\"x\":-0.9887177923487853,\"y\":0.5948092751786125},{\"x\":-0.9669049841354317,\"y\":0.040239350741894025}],\"638cc5b5-9869-45ce-9def-a5b5e48c15c1\":[{\"x\":\"nya1\",\"y\":10},{\"x\":\"nya2\",\"y\":20},{\"x\":\"nya3\",\"y\":30}],\"41f4dad2-245b-419c-a35f-a8a38dbe629d\":[{\"x\":29.850124958340775,\"y\":2.9950024994048445},{\"x\":4.126678074548392,\"y\":2.823212366975177},{\"x\":1.2370803311606653,\"y\":2.430565527440278},{\"x\":-0.05474910431491652,\"y\":1.8742005057028222},{\"x\":-0.7212087208569393,\"y\":1.2331562380698196},{\"x\":-0.9887177923487853,\"y\":0.5948092751786125},{\"x\":-0.9669049841354317,\"y\":0.040239350741894025}],\"16c0d18f-9207-4eff-a1c0-8d0bda12658f\":[{\"x\":0,\"y\":10},{\"x\":1,\"y\":20},{\"x\":2,\"y\":30}]}}\n        Nyaplot.core.parse(model, '#vis-4f80222f-8687-4e9a-a921-11d3a2059af4');\n    };\n    if(window['Nyaplot']==undefined){\n        window.addEventListener('load_nyaplot', render, false);\n\treturn;\n    }\n    render();\n})();\n</script>\n"
