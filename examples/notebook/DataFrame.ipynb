# %% [markdown]
# # DataFrame demo

# %%
require 'nyaplot'
# Out:
# "if(window['d3'] === undefined ||\n   window['Nyaplot'] === undefined){\n    var path = {\"d3\":\"http://d3js.org/d3.v3.min\"};\n\n\n\n    var shim = {\"d3\":{\"exports\":\"d3\"}};\n\n    require.config({paths: path, shim:shim});\n\n\nrequire(['d3'], function(d3){window['d3']=d3;console.log('finished loading d3');\n\n\tvar script = d3.select(\"head\")\n\t    .append(\"script\")\n\t    .attr(\"src\", \"https://rawgit.com/domitry/Nyaplotjs/master/release/nyaplot.js\")\n\t    .attr(\"async\", true);\n\n\tscript[0][0].onload = script[0][0].onreadystatechange = function(){\n\n\n\t    var event = document.createEvent(\"HTMLEvents\");\n\t    event.initEvent(\"load_nyaplot\",false,false);\n\t    window.dispatchEvent(event);\n\t    console.log('Finished loading Nyaplotjs');\n\n\t};\n\n\n});\n}\n"
# true

# %%
df1 = Nyaplot::DataFrame.new({a:[1,2,3], b:[10,8,9]})
# Out:
# #<Nyaplot::DataFrame:0xb8769f7c @name="1124dd87-e472-4bcc-8097-bfe8330263dc", @rows=[{:a=>1, :b=>10}, {:a=>2, :b=>8}, {:a=>3, :b=>9}]>

# %%
path = File.expand_path("../data/first.tab", __FILE__)
df2 = Nyaplot::DataFrame.from_csv(path, ' ')
# Out:
# #<Nyaplot::DataFrame:0xb860e4fc @name="939de4f9-9651-40c8-bea9-90485c463635", @rows=[{:mutation=>"G>A", :blood=>0.0, :set1=>0.019230769230769232, :set2=>0.0, :set3=>0.48214285714285715, :set12=>0.0, :set21=>0.0, :set31=>0.4782608695652174}, {:mutation=>"C>T", :blood=>0.0, :set1=>0.42592592592592593, :set2=>0.0, :set3=>0.0, :set12=>0.375, :set21=>0.0, :set31=>0.0}, {:mutation=>"C>G", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.525, :set31=>0.0}, {:mutation=>"C>A", :blood=>0.0, :set1=>0.0, :set2=>0.1935483870967742, :set3=>0.0, :set12=>0.0, :set21=>0.4666666666666667, :set31=>0.0}, {:mutation=>"C>A", :blood=>0.0, :set1=>0.0, :set2=>0.08333333333333333, :set3=>0.0, :set12=>0.0, :set21=>0.5161290322580645, :set31=>0.0}, {:mutation=>"G>T", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.4444444444444444, :set21=>0.0, :set31=>0.0}, {:mutation=>"C>G", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.0, :set31=>0.4}, {:mutation=>"C>A", :blood=>0.0, :set1=>0.0, :set2=>0.03333333333333333, :set3=>0.0, :set12=>0.0, :set21=>0.42857142857142855, :set31=>0.0}, {:mutation=>"A>C", :blood=>0.0, :set1=>0.6153846153846154, :set2=>0.0, :set3=>0.0, :set12=>0.5925925925925926, :set21=>0.0, :set31=>0.0}, {:mutation=>"C>A", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.32, :set31=>0.0}, {:mutation=>"C>A", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.4230769230769231, :set31=>0.0}, {:mutation=>"T>A", :blood=>0.0, :set1=>0.525, :set2=>0.0, :set3=>0.0, :set12=>0.5277777777777778, :set21=>0.0, :set31=>0.0}, {:mutation=>"C>T", :blood=>0.0, :set1=>0.42857142857142855, :set2=>0.0, :set3=>0.0, :set12=>0.6666666666666666, :set21=>0.0, :set31=>0.0}, {:mutation=>"G>A", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.5, :set31=>0.03225806451612903}, {:mutation=>"T>C", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.0, :set31=>0.3793103448275862}, {:mutation=>"C>T", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.45714285714285713, :set12=>0.0, :set21=>0.0, :set31=>0.46875}, {:mutation=>"C>A", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.5142857142857142, :set21=>0.0, :set31=>0.0}, {:mutation=>"C>A", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.0, :set31=>0.43478260869565216}, {:mutation=>"G>C", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.6857142857142857, :set21=>0.0, :set31=>0.0}, {:mutation=>"G>A", :blood=>0.0, :set1=>0.45652173913043476, :set2=>0.0, :set3=>0.0, :set12=>0.43478260869565216, :set21=>0.0, :set31=>0.0}, {:mutation=>"C>T", :blood=>0.0, :set1=>0.09803921568627451, :set2=>0.0, :set3=>0.0, :set12=>0.37142857142857144, :set21=>0.0, :set31=>0.0}, {:mutation=>"G>T", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.52, :set21=>0.0, :set31=>0.0}, {:mutation=>"T>A", :blood=>0.0, :set1=>0.5769230769230769, :set2=>0.0, :set3=>0.0, :set12=>0.4782608695652174, :set21=>0.0, :set31=>0.0}, {:mutation=>"A>G", :blood=>0.0, :set1=>0.43859649122807015, :set2=>0.0, :set3=>0.0, :set12=>0.5142857142857142, :set21=>0.0, :set31=>0.0}, {:mutation=>"T>C", :blood=>0.0, :set1=>0.5806451612903226, :set2=>0.0, :set3=>0.0, :set12=>0.6341463414634146, :set21=>0.0, :set31=>0.0}, {:mutation=>"A>C", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.40476190476190477, :set31=>0.0}, {:mutation=>"C>T", :blood=>0.0, :set1=>0.0, :set2=>0.14705882352941177, :set3=>0.0, :set12=>0.0, :set21=>0.5813953488372093, :set31=>0.0}, {:mutation=>"C>A", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.0, :set12=>0.0, :set21=>0.45714285714285713, :set31=>0.0}, {:mutation=>"G>A", :blood=>0.0, :set1=>0.0, :set2=>0.5581395348837209, :set3=>0.0, :set12=>0.0, :set21=>0.5151515151515151, :set31=>0.0}, {:mutation=>"C>T", :blood=>0.0, :set1=>0.0, :set2=>0.0, :set3=>0.46808510638297873, :set12=>0.0, :set21=>0.0, :set31=>0.6923076923076923}, {:mutation=>"G>A", :blood=>0 ...

# %%
df2.row(0)
# Out:
# {:mutation=>"G>A", :blood=>0.0, :set1=>0.019230769230769232, :set2=>0.0, :set3=>0.48214285714285715, :set12=>0.0, :set21=>0.0, :set31=>0.4782608695652174}

# %%
df2.filter {|row| row[:SET1]!=0.0}
# Out:
# #<Nyaplot::DataFrame:0xb9441240 @name="72d44281-1245-4725-88bd-7407c24452c1", @rows=[{:mutation=>"G>A", :BLOOD=>0.0, :SET1=>0.019230769230769232, :SET2=>0.0, :SET3=>0.48214285714285715, :"SET1.2"=>0.0, :"SET2.1"=>0.0, :"SET3.1"=>0.4782608695652174}, {:mutation=>"C>T", :BLOOD=>0.0, :SET1=>0.42592592592592593, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.375, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"A>C", :BLOOD=>0.0, :SET1=>0.6153846153846154, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5925925925925926, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"T>A", :BLOOD=>0.0, :SET1=>0.525, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5277777777777778, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"C>T", :BLOOD=>0.0, :SET1=>0.42857142857142855, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.6666666666666666, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"G>A", :BLOOD=>0.0, :SET1=>0.45652173913043476, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.43478260869565216, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"C>T", :BLOOD=>0.0, :SET1=>0.09803921568627451, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.37142857142857144, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"T>A", :BLOOD=>0.0, :SET1=>0.5769230769230769, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.4782608695652174, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"A>G", :BLOOD=>0.0, :SET1=>0.43859649122807015, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5142857142857142, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"T>C", :BLOOD=>0.0, :SET1=>0.5806451612903226, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.6341463414634146, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"G>A", :BLOOD=>0.0, :SET1=>0.014705882352941176, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.0, :"SET2.1"=>0.0, :"SET3.1"=>0.41935483870967744}, {:mutation=>"G>A", :BLOOD=>0.0, :SET1=>0.6666666666666666, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"C>T", :BLOOD=>0.0, :SET1=>0.532258064516129, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5227272727272727, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"G>A", :BLOOD=>0.0, :SET1=>0.5652173913043478, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.3870967741935484, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"G>A", :BLOOD=>0.0, :SET1=>0.42857142857142855, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.3333333333333333, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"C>A", :BLOOD=>0.0, :SET1=>0.4888888888888889, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.43243243243243246, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"C>A", :BLOOD=>0.0, :SET1=>0.01818181818181818, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.0, :"SET2.1"=>0.0, :"SET3.1"=>0.43478260869565216}, {:mutation=>"C>A", :BLOOD=>0.0, :SET1=>0.45098039215686275, :SET2=>0.03225806451612903, :SET3=>0.0, :"SET1.2"=>0.5882352941176471, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"A>T", :BLOOD=>0.0, :SET1=>0.5172413793103449, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.43333333333333335, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"T>C", :BLOOD=>0.0, :SET1=>0.04878048780487805, :SET2=>0.0, :SET3=>0.019230769230769232, :"SET1.2"=>0.6060606060606061, :"SET2.1"=>0.5662650602409639, :"SET3.1"=>0.6296296296296297}, {:mutation=>"G>A", :BLOOD=>0.0, :SET1=>0.4375, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"C>A", :BLOOD=>0.0, :SET1=>0.4782608695652174, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.4642857142857143, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"T>G", :BLOOD=>0.0, :SET1=>0.66, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5185185185185185, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"A>T", :BLOOD=>0.0, :SET1=>0.018518518518518517, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5833333333333334, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"G>A", :BLOOD=>0.0, :SET1=>0.45, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.35714285714285715, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"C>A", :BLOOD=>0.0, :SET1=>0.49230769230769234, :SET2=>0.0, :SET3=>0.0, :"SET1.2"=>0.5161290322580645, :"SET2.1"=>0.0, :"SET3.1"=>0.0}, {:mutation=>"A>C", :BLOOD=>0.0, :SET1=>0.48333333333333334, :SET2=>0.0, :SET3=>0.0, :"SE ...
